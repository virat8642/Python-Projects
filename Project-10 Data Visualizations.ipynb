# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x = np.random.normal(size=400)

# %%
plt.plot(x)

# %%
plt.plot(x.cumsum())

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('ggplot')

# %%
plt.plot(x.cumsum());

# %%
y = np.random.normal(size=400)

# %%
plt.plot(y.cumsum());

# %%
plt.plot(x.cumsum());
plt.plot(y.cumsum());

# %%
plt.plot(x.cumsum(), label='x')
plt.plot(y.cumsum(), label='y', color='purple')
plt.legend();

# %%
figures, axes = plt.subplots()
axes.plot(x.cumsum(), label='x')
axes.plot(y.cumsum(), label='y')
axes.legend(loc='upper left')

figures.set_size_inches(10,2);

# %%
brent = pd.read_csv('C:\download\course softwares\The Ultimate Pandas Bootcamp Advanced Python Data Analysis\[TutsNode.com] - The Ultimate Pandas Bootcamp Advanced Python Data Analysis\Sources\BrentOilPrices.csv')

# %%
brent.head()
# Out:
#         Date  Price
# 0  04-Jan-00  23.95
# 1  05-Jan-00  23.72
# 2  06-Jan-00  23.55
# 3  07-Jan-00  23.35
# 4  10-Jan-00  22.77

# %%
brent.plot();

# %%
tech = pd.read_csv('C:/download/course softwares/The Ultimate Pandas Bootcamp Advanced Python Data Analysis/python practice files/Sources/tech_giants.csv',index_col=0,parse_dates=True)

# %%
tech.head()
# Out:
#             month  year  day   name    open   close    high     low    volume  \
# date
# 2014-01-02      1  2014    2     FB   54.86   54.71   55.22   54.19  43257622
# 2014-01-02      1  2014    2   AAPL   79.38   79.02   79.58   78.86   8398851
# 2014-01-02      1  2014    2  GOOGL  557.73  556.56  558.88  554.13   1822719
# 2014-01-02      1  2014    2   MSFT   37.35   37.16   37.40   37.10  30643745
# 2014-01-02      1  2014    2   AMZN  398.80  397.97  399.36  394.02   2140246
#
#            volume_type
# date
# 2014-01-02      medium
# 2014-01-02         low
# 2014-01-02      medium
# 2014-01-02      medium
# 2014-01-02      medium

# %%
fb = tech.loc[tech.name=='FB','close'].rename('Facebook')
msft = tech.loc[tech.name=='MSFT','close'].rename('Microsoft')
aapl = tech.loc[tech.name=='AAPL','close'].rename('Apple')

# %%
dfs = pd.concat([fb,msft,aapl], axis=1)

# %%
dfs.plot();

# %%
dfs.plot(subplots=True, linewidth=.7, figsize=(13,6));

# %%
boston = pd.read_csv('C:/download/course softwares/The Ultimate Pandas Bootcamp Advanced Python Data Analysis/python practice files/Sources/bostonmarathon.csv')

# %%
boston.head()
# Out:
#                 Name  Age M/F           City State Country Official Time  \
# 0   Kirui, Geoffrey    24   M       Keringet   NaN     KEN       2:09:37
# 1     Rupp, Galen      30   M       Portland    OR     USA       2:09:58
# 2    Osako, Suguru     25   M   Machida-City   NaN     JPN       2:10:28
# 3   Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA       2:12:08
# 4     Chebet, Wilson   31   M       Marakwet   NaN     KEN       2:12:35
#
#    Overall  Gender Years Ran
# 0        1       1       NaN
# 1        2       2       NaN
# 2        3       3       NaN
# 3        4       4       NaN
# 4        5       5      2015

# %%
boston.Age.value_counts().plot();

# %%
ax = boston.Age.value_counts(sort=False).plot(kind='bar' , figsize=(12,6))
ax.set_label('Age Group')
ax.set_label('No of runners');

# %%
ax = boston.Age.value_counts(ascending=True).plot(kind='barh' , figsize=(12,12))
ax.set_label('Age Group')
ax.set_label('No of runners');

# %%
games = pd.read_csv('C:\download\course softwares\The Ultimate Pandas Bootcamp Advanced Python Data Analysis\[TutsNode.com] - The Ultimate Pandas Bootcamp Advanced Python Data Analysis\Sources\games_sales.csv')

# %%
games.head()
# Out:
#                              Name Platform    Year    Genre  \
# 0              Kinect Adventures!     X360  2010.0     Misc
# 1              Grand Theft Auto V      PS3  2013.0   Action
# 2              Grand Theft Auto V     X360  2013.0   Action
# 3  Call of Duty: Modern Warfare 3     X360  2011.0  Shooter
# 4         Call of Duty: Black Ops     X360  2010.0  Shooter
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0  Microsoft Game Studios     14.97      4.94      0.24         1.67
# 1    Take-Two Interactive      7.01      9.27      0.97         4.14
# 2    Take-Two Interactive      9.63      5.31      0.06         1.38
# 3              Activision      9.03      4.28      0.13         1.32
# 4              Activision      9.67      3.73      0.11         1.13
#
#    Global_Sales
# 0         21.82
# 1         21.40
# 2         16.38
# 3         14.76
# 4         14.64

# %%
games.NA_Sales
# Out:
# 0       14.97
# 1        7.01
# 2        9.63
# 3        9.03
# 4        9.67
#         ...
# 3138     0.00
# 3139     0.01
# 3140     0.01
# 3141     0.00
# 3142     0.00
# Name: NA_Sales, Length: 3143, dtype: float64

# %%
games.groupby('Platform').NA_Sales.sum().plot(kind='pie',figsize=(6,6));

# %%
games.loc[:, ['NA_Sales','JP_Sales','Platform']].groupby('Platform').sum()
# Out:
#           NA_Sales  JP_Sales
# Platform
# PS3         392.26     79.99
# PS4          96.80     14.30
# X360        601.05     12.43
# XOne         83.19      0.34

# %%
games.loc[:, ['NA_Sales','JP_Sales','Platform']].groupby('Platform').sum().plot(kind='pie', subplots=True,figsize=(13,6));

# %%
drinks = pd.read_csv('C:\download\course softwares\The Ultimate Pandas Bootcamp Advanced Python Data Analysis\python practice files\Sources\drinks.csv')

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            NaN              NaN            NaN
# 1      Albania           89.0            132.0           54.0
# 2      Algeria           25.0              NaN           14.0
# 3      Andorra          245.0            138.0          312.0
# 4       Angola          217.0             57.0           45.0
#
#    total_litres_of_pure_alcohol
# 0                           NaN
# 1                           4.9
# 2                           0.7
# 3                          12.4
# 4                           5.9

# %%
ax = drinks.beer_servings.plot(kind='hist')
ax.set_xlabel('Beer Servings');

# %%
ax = drinks.beer_servings.plot(kind='hist',bins=5,orientation='horizontal')
ax.set_xlabel('Beer Servings');

# %%
drinks.loc[:,'beer_servings':'wine_servings'].plot(kind='hist');

# %%
drinks.loc[:,'beer_servings':'wine_servings'].plot(kind='hist',subplots=True,figsize=(10,10), alpha=0.8);

# %%
sat = pd.read_csv('C:\download\course softwares\The Ultimate Pandas Bootcamp Advanced Python Data Analysis\[TutsNode.com] - The Ultimate Pandas Bootcamp Advanced Python Data Analysis\Sources\satscores.csv')

# %%
sat.head()
# Out:
#                              School Name    Borough  Student Enrollment  \
# 0  A. Philip Randolph Campus High School  Manhattan                1354
# 1  A. Philip Randolph Campus High School  Manhattan                1354
# 2  A. Philip Randolph Campus High School  Manhattan                1354
# 3            Abraham Lincoln High School   Brooklyn                2341
# 4            Abraham Lincoln High School   Brooklyn                2341
#
#   Percent Tested SAT Section  Score
# 0         74.00%        Math    459
# 1         74.00%     Reading    453
# 2         74.00%     Writing    447
# 3         54.90%        Math    441
# 4         54.90%     Reading    422

# %%
math = sat[sat['SAT Section']=='Math'].Score.reset_index(drop=True)
writing = sat[sat['SAT Section']=='Writing'].Score.reset_index(drop=True)
reading = sat[sat['SAT Section']=='Reading'].Score.reset_index(drop=True)

# %%
scores = pd.concat([math,writing,reading], axis=1)
scores.columns = ['Math','Writing','Reading']

# %%
scores
# Out:
#      Math  Writing  Reading
# 0     459      447      453
# 1     441      422      422
# 2     444      444      458
# 3     386      393      397
# 4     381      390      397
# ..    ...      ...      ...
# 370   484      487      491
# 371   496      473      481
# 372   478      472      465
# 373   483      477      464
# 374   415      433      420
#
# [375 rows x 3 columns]

# %%
scores.plot(kind='scatter',x='Math',y='Writing');

# %%
math.corr(writing)
# Out:
# 0.9341552744743191

# %%
scores.plot(kind='scatter',x='Reading',y='Writing');

# %%
reading.corr(writing)
# Out:
# 0.9854389581058104

# %%
scores.head()
# Out:
#    Math  Writing  Reading
# 0   459      447      453
# 1   441      422      422
# 2   444      444      458
# 3   386      393      397
# 4   381      390      397

# %%
import seaborn as sns

# %%
sns.jointplot('Math','Writing',scores,kind='scatter');
# Out:
# C:\Users\virat\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot('Math','Writing',scores,kind='hex');
# Out:
# C:\Users\virat\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
games.head()
# Out:
#                              Name Platform    Year    Genre  \
# 0              Kinect Adventures!     X360  2010.0     Misc
# 1              Grand Theft Auto V      PS3  2013.0   Action
# 2              Grand Theft Auto V     X360  2013.0   Action
# 3  Call of Duty: Modern Warfare 3     X360  2011.0  Shooter
# 4         Call of Duty: Black Ops     X360  2010.0  Shooter
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0  Microsoft Game Studios     14.97      4.94      0.24         1.67
# 1    Take-Two Interactive      7.01      9.27      0.97         4.14
# 2    Take-Two Interactive      9.63      5.31      0.06         1.38
# 3              Activision      9.03      4.28      0.13         1.32
# 4              Activision      9.67      3.73      0.11         1.13
#
#    Global_Sales
# 0         21.82
# 1         21.40
# 2         16.38
# 3         14.76
# 4         14.64

# %%
games.groupby('Platform').Global_Sales.sum().plot(kind='pie',figsize=(5,5));

# %%
games.head()
# Out:
#                              Name Platform    Year    Genre  \
# 0              Kinect Adventures!     X360  2010.0     Misc
# 1              Grand Theft Auto V      PS3  2013.0   Action
# 2              Grand Theft Auto V     X360  2013.0   Action
# 3  Call of Duty: Modern Warfare 3     X360  2011.0  Shooter
# 4         Call of Duty: Black Ops     X360  2010.0  Shooter
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0  Microsoft Game Studios     14.97      4.94      0.24         1.67
# 1    Take-Two Interactive      7.01      9.27      0.97         4.14
# 2    Take-Two Interactive      9.63      5.31      0.06         1.38
# 3              Activision      9.03      4.28      0.13         1.32
# 4              Activision      9.67      3.73      0.11         1.13
#
#    Global_Sales
# 0         21.82
# 1         21.40
# 2         16.38
# 3         14.76
# 4         14.64

# %%
sports_games = games.loc[games.Genre=='Sports',['Name','Global_Sales']].groupby('Name').sum()

# %%
sports_games
# Out:
#                                   Global_Sales
# Name
# 2010 FIFA World Cup South Africa          2.09
# 2014 FIFA World Cup Brazil                1.18
# After Hours Athletes                      0.12
# All-Pro Football 2K8                      0.41
# Amped 3                                   0.16
# ...                                        ...
# Your Shape: Fitness Evolved               1.33
# Your Shape: Fitness Evolved 2012          1.17
# Zumba Fitness                             2.98
# Zumba Fitness Rush                        0.19
# pro evolution soccer 2011                 3.03
#
# [288 rows x 1 columns]

# %%
sports_games.nlargest(20, columns='Global_Sales').plot(kind='bar',figsize=(10,10));
