# %%
import pandas as pd
import numpy as np

# %%
players = pd.read_csv('C:\download\course softwares\The Ultimate Pandas Bootcamp Advanced Python Data Analysis\python practice files\Sources\soccer.csv')

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
players[players.market_value>40]
# Out:
#                   name               club  age position  position_cat  \
# 0       Alexis Sanchez            Arsenal   28       LW             1
# 1           Mesut Ozil            Arsenal   28       AM             1
# 96         Eden Hazard            Chelsea   26       LW             1
# 97         Diego Costa            Chelsea   28       CF             1
# 108     N%27Golo Kante            Chelsea   26       DM             2
# 218  Philippe Coutinho          Liverpool   25       AM             1
# 244    Kevin De Bruyne    Manchester+City   26       AM             1
# 245      Sergio Aguero    Manchester+City   29       CF             1
# 246    Raheem Sterling    Manchester+City   22       LW             1
# 264      Romelu Lukaku  Manchester+United   24       CF             1
# 267         Paul Pogba  Manchester+United   24       CM             2
# 380          Dele Alli          Tottenham   21       CM             2
# ...

# %%
players.position.unique()
# Out:
# array(['LW', 'AM', 'GK', 'RW', 'CB', 'RB', 'CF', 'LB', 'DM', 'RM', 'CM',
#        nan, 'SS', 'LM'], dtype=object)

# %%
players[players.position.isin(['LB','CB','RB'])]
# Out:
#                   name      club  age position  position_cat  market_value  \
# 4    Laurent Koscielny   Arsenal   31       CB             3          22.0
# 5      Hector Bellerin   Arsenal   22       RB             3          30.0
# 7        Nacho Monreal   Arsenal   31       LB             3          13.0
# 8     Shkodran Mustafi   Arsenal   25       CB             3          30.0
# 17    Gabriel Paulista   Arsenal   26       CB             3          13.0
# ..                 ...       ...  ...      ...           ...           ...
# 455    Aaron Cresswell  West+Ham   27       LB             3          12.0
# 458     Angelo Ogbonna  West+Ham   29       CB             3           9.0
# 459     Pablo Zabaleta  West+Ham   32       RB             3           7.0
# 461     Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462          Sam Byram  West+Ham   23       RB             3           4.5
#
# ...

# %%
players[players.market_value.between (40,50)]
# Out:
#                     name               club  age position  position_cat  \
# 1             Mesut Ozil            Arsenal   28       AM             1
# 31   Alexandre Lacazette            Arsenal   26       CF             1
# 97           Diego Costa            Chelsea   28       CF             1
# 102     Thibaut Courtois            Chelsea   25       GK             4
# 108       N%27Golo Kante            Chelsea   26       DM             2
# 218    Philippe Coutinho          Liverpool   25       AM             1
# 219           Sadio Mane          Liverpool   25       LW             1
# 246      Raheem Sterling    Manchester+City   22       LW             1
# 263       Bernardo Silva    Manchester+City   22       RW             1
# 264        Romelu Lukaku  Manchester+United   24       CF             1
# 265         David de Gea  Manchester+United   26       GK             4
# 380            Dele Alli          Tottenham   21       CM             2
# ...

# %%
players[players.age<=25]
# Out:
#                     name      club  age position  position_cat  market_value  \
# 5        Hector Bellerin   Arsenal   22       RB             3          30.0
# 8       Shkodran Mustafi   Arsenal   25       CB             3          30.0
# 9             Alex Iwobi   Arsenal   21       LW             1          10.0
# 10          Granit Xhaka   Arsenal   24       DM             2          35.0
# 11          Granit Xhaka   Arsenal   24       DM             2          35.0
# ..                   ...       ...  ...      ...           ...           ...
# 456         Pedro Obiang  West+Ham   25       CM             2           9.0
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
#
# ...

# %%
players[ (players.position=='LB') & (players.age<=25)]
# Out:
#                  name               club  age position  position_cat  \
# 29     Sead Kolasinac            Arsenal   24       LB             3
# 54         Brad Smith        Bournemouth   23       LB             3
# 112            Kenedy            Chelsea   21       LB             3
# 128   Jeffrey Schlupp     Crystal+Palace   24       LB             3
# 212      Ben Chilwell     Leicester+City   20       LB             3
# 236    Alberto Moreno          Liverpool   25       LB             3
# 281         Luke Shaw  Manchester+United   22       LB             3
# 294      Paul Dummett   Newcastle+United   25       LB             3
# 298  Massadio Haidara   Newcastle+United   24       LB             3
# 328      Matt Targett        Southampton   21       LB             3
# 354        Josh Tymon         Stoke+City   18       LB             3
# 369  Stephen Kingsley            Swansea   22       LB             3
# 389        Ben Davies          Tottenham   24       LB             3
# ...

# %%
players[ (players.position=='LB') & (players.age<=25)&(players.market_value>=10)&~(players.club.isin(['Tottenham','Arsenal']))]
# Out:
#                name               club  age position  position_cat  \
# 236  Alberto Moreno          Liverpool   25       LB             3
# 281       Luke Shaw  Manchester+United   22       LB             3
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 236          10.0         397        4.5   0.30%           8       2
# 281          20.0         947        5.0   0.40%          45       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 236       Spain            0        3       10         1            0
# 281     England            0        2       12         1            0

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
arsenal_player = players.club == 'Arsenal'

# %%
arsenal_player
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Name: club, Length: 465, dtype: bool

# %%
right_back = players.position == 'RB'

# %%
right_back
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461    False
# 462     True
# 463    False
# 464    False
# Name: position, Length: 465, dtype: bool

# %%
chelsea_and_GK = (players.club == 'Chelsea') & (players.position == 'GK')

# %%
chelsea_and_GK
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Length: 465, dtype: bool

# %%
players.loc[arsenal_player & right_back | chelsea_and_GK]
# Out:
#                  name     club  age position  position_cat  market_value  \
# 5     Hector Bellerin  Arsenal   22       RB             3          30.0
# 27     Carl Jenkinson  Arsenal   25       RB             3           5.0
# 102  Thibaut Courtois  Chelsea   25       GK             4          40.0
# 109   Willy Caballero  Chelsea   35       GK             4           1.5
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 5          1675        6.0  13.70%         119       2       Spain
# 27          561        4.5   0.40%           2       1     England
# 102        1260        5.5  18.50%         141       2     Belgium
# 109         542        5.0   0.20%          64       3   Argentina
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 5              0        2        1         1            0
# 27             0        3        1         1            0
# 102            0        3        5         1            0
# ...

# %%
english = players.nationality == 'England'

# %%
english
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 460    False
# 461    False
# 462     True
# 463     True
# 464    False
# Name: nationality, Length: 465, dtype: bool

# %%
players.market_value.mean()
# Out:
# 11.125649350649349

# %%
above_avg = players.market_value > players.market_value.mean()*2

# %%
above_avg.head()
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# Name: market_value, dtype: bool

# %%
popular_new = (players.page_views>4000)^(players.new_signing==1)

# %%
popular_new
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 460     True
# 461     True
# 462    False
# 463     True
# 464    False
# Length: 465, dtype: bool

# %%
players.loc[english & above_avg & popular_new ]
# Out:
#             name             club  age position  position_cat  market_value  \
# 256  John Stones  Manchester+City   23       CB             3          35.0
# 380    Dele Alli        Tottenham   21       CM             2          45.0
# 381   Harry Kane        Tottenham   23       CF             1          60.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 256        1078        5.5   2.30%          59       1     England
# 380        4626        9.5  38.60%         225       1     England
# 381        4161       12.5  35.10%         224       1     England
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 256            0        2       11         1            1
# 380            0        1       17         1            0
# 381            0        2       17         1            0

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
chelsea_23under = (players.club == 'Chelsea') & (players.age<=23)

# %%
players[chelsea_23under]
# Out:
#                  name     club  age position  position_cat  market_value  \
# 110   Michy Batshuayi  Chelsea   23       CF             1          25.0
# 111        Kurt Zouma  Chelsea   22       CB             3          15.0
# 112            Kenedy  Chelsea   21       LB             3           7.0
# 115  Tiemoue Bakayoko  Chelsea   22       DM             2          16.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 110        1162        8.5   1.60%          48       2     Belgium
# 111         723        5.5   0.80%          15       2      France
# 112         566        5.0   0.10%           3       3      Brazil
# 115        1011        5.0   1.60%           0       2      France
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 110            0        2        5         1            1
# 111            0        2        5         1            0
# 112            0        1        5         1            0
# ...

# %%
players.loc[chelsea_23under,['position','market_value']]
# Out:
#     position  market_value
# 110       CF          25.0
# 111       CB          15.0
# 112       LB           7.0
# 115       DM          16.0

# %%
p_cols = players.columns.str.startswith('p')

# %%
players.loc[chelsea_23under,p_cols]
# Out:
#     position  position_cat  page_views
# 110       CF             1        1162
# 111       CB             3         723
# 112       LB             3         566
# 115       DM             2        1011

# %%
players.loc[chelsea_23under,'position']
# Out:
# 110    CF
# 111    CB
# 112    LB
# 115    DM
# Name: position, dtype: object

# %%
players.loc[[0,132] , ('name','market_value')]
# Out:
#                name  market_value
# 0    Alexis Sanchez          65.0
# 132  Connor Wickham           6.0

# %%
players.sort_values('market_value',ascending=False)
# Out:
#                     name               club  age position  position_cat  \
# 96           Eden Hazard            Chelsea   26       LW             1
# 267           Paul Pogba  Manchester+United   24       CM             2
# 0         Alexis Sanchez            Arsenal   28       LW             1
# 244      Kevin De Bruyne    Manchester+City   26       AM             1
# 245        Sergio Aguero    Manchester+City   29       CF             1
# ..                   ...                ...  ...      ...           ...
# 287  Joel Castro Pereira  Manchester+United   21       GK             4
# 113     Eduardo Carvalho            Chelsea   34       LW             1
# 30          Granit Xhaka            Arsenal   24      NaN             2
# 192         Steve Mounie       Huddersfield   22       CF             1
# 195    Kasper Schmeichel     Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# ...

# %%
players.sort_index(axis=1)
# Out:
#      age  age_cat  big_club      club  club_id  fpl_points fpl_sel  fpl_value  \
# 0     28        4         1   Arsenal        1         264  17.10%       12.0
# 1     28        4         1   Arsenal        1         167   5.60%        9.5
# 2     35        6         1   Arsenal        1         134   5.90%        5.5
# 3     28        4         1   Arsenal        1         122   1.50%        7.5
# 4     31        4         1   Arsenal        1         121   0.70%        6.0
# ..   ...      ...       ...       ...      ...         ...     ...        ...
# 460   21        1         0  West+Ham       20          38   0.40%        4.5
# 461   23        2         0  West+Ham       20          34   0.20%        4.5
# 462   23        2         0  West+Ham       20          29   0.30%        4.5
# 463   21        1         0  West+Ham       20          16   5.90%        4.5
# 464   27        3         0  West+Ham       20          12   0.10%        5.5
#
# ...

# %%
players.reset_index()
# Out:
#      index                 name      club  age position  position_cat  \
# 0        0       Alexis Sanchez   Arsenal   28       LW             1
# 1        1           Mesut Ozil   Arsenal   28       AM             1
# 2        2            Petr Cech   Arsenal   35       GK             4
# 3        3         Theo Walcott   Arsenal   28       RW             1
# 4        4    Laurent Koscielny   Arsenal   31       CB             3
# ..     ...                  ...       ...  ...      ...           ...
# 460    460  Edimilson Fernandes  West+Ham   21       CM             2
# 461    461       Arthur Masuaku  West+Ham   23       LB             3
# 462    462            Sam Byram  West+Ham   23       RB             3
# 463    463      Ashley Fletcher  West+Ham   21       CF             1
# 464    464         Diafra Sakho  West+Ham   27       CF             1
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# ...

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
players_lite = players.iloc[:4,:4]

# %%
players_lite
# Out:
#              name     club  age position
# 0  Alexis Sanchez  Arsenal   28       LW
# 1      Mesut Ozil  Arsenal   28       AM
# 2       Petr Cech  Arsenal   35       GK
# 3    Theo Walcott  Arsenal   28       RW

# %%
players_lite.reindex(index=[2,1,3,0] , columns=['age','name','position','club'])
# Out:
#    age            name position     club
# 2   35       Petr Cech       GK  Arsenal
# 1   28      Mesut Ozil       AM  Arsenal
# 3   28    Theo Walcott       RW  Arsenal
# 0   28  Alexis Sanchez       LW  Arsenal

# %%
players.reindex(index=[2,1,3,0]).sort_index(axis=1)
# Out:
#    age  age_cat  big_club     club  club_id  fpl_points fpl_sel  fpl_value  \
# 2   35        6         1  Arsenal        1         134   5.90%        5.5
# 1   28        4         1  Arsenal        1         167   5.60%        9.5
# 3   28        4         1  Arsenal        1         122   1.50%        7.5
# 0   28        4         1  Arsenal        1         264  17.10%       12.0
#
#    market_value            name     nationality  new_foreign  new_signing  \
# 2           7.0       Petr Cech  Czech Republic            0            0
# 1          50.0      Mesut Ozil         Germany            0            0
# 3          20.0    Theo Walcott         England            0            0
# 0          65.0  Alexis Sanchez           Chile            0            0
#
#    page_views position  position_cat  region
# 2        1529       GK             4       2
# 1        4395       AM             1       2
# 3        2393       RW             1       1
# ...

# %%
players.reindex(index=[2,1,3,0],columns=sorted(players.columns)[:6])
# Out:
#    age  age_cat  big_club     club  club_id  fpl_points
# 2   35        6         1  Arsenal        1         134
# 1   28        4         1  Arsenal        1         167
# 3   28        4         1  Arsenal        1         122
# 0   28        4         1  Arsenal        1         264

# %%
players.reindex(index=[2,1,3,0],columns=players.columns.sort_values())
# Out:
#    age  age_cat  big_club     club  club_id  fpl_points fpl_sel  fpl_value  \
# 2   35        6         1  Arsenal        1         134   5.90%        5.5
# 1   28        4         1  Arsenal        1         167   5.60%        9.5
# 3   28        4         1  Arsenal        1         122   1.50%        7.5
# 0   28        4         1  Arsenal        1         264  17.10%       12.0
#
#    market_value            name     nationality  new_foreign  new_signing  \
# 2           7.0       Petr Cech  Czech Republic            0            0
# 1          50.0      Mesut Ozil         Germany            0            0
# 3          20.0    Theo Walcott         England            0            0
# 0          65.0  Alexis Sanchez           Chile            0            0
#
#    page_views position  position_cat  region
# 2        1529       GK             4       2
# 1        4395       AM             1       2
# 3        2393       RW             1       1
# ...

# %%
players.sort_values('age',ascending=True)
# Out:
#                        name               club  age position  position_cat  \
# 237            Ben Woodburn          Liverpool   17       LW             1
# 354              Josh Tymon         Stoke+City   18       LB             3
# 439           Jonathan Leko          West+Brom   18       RW             1
# 235  Trent Alexander-Arnold          Liverpool   18       RB             3
# 274         Marcus Rashford  Manchester+United   19       CF             1
# ..                      ...                ...  ...      ...           ...
# 340            Peter Crouch         Stoke+City   36       CF             1
# 150            Gareth Barry            Everton   36       DM             2
# 35              Artur Boruc        Bournemouth   37       GK             4
# 424          Gareth McAuley          West+Brom   37       CB             3
# 136          Julian Speroni     Crystal+Palace   38       GK             4
#
# ...

# %%
players.loc[players.age.idxmin()]
# Out:
# name            Ben Woodburn
# club               Liverpool
# age                       17
# position                  LW
# position_cat               1
# market_value             1.5
# page_views              1241
# fpl_value                4.5
# fpl_sel                0.10%
# fpl_points                 5
# region                     1
# nationality            Wales
# new_foreign                0
# age_cat                    1
# club_id                   10
# big_club                   1
# new_signing                0
# Name: 237, dtype: object

# %%
players.set_index('club').sort_index()
# Out:
#                          name  age position  position_cat  market_value  \
# club
# Arsenal        Alexis Sanchez   28       LW             1          65.0
# Arsenal            Mesut Ozil   28       AM             1          50.0
# Arsenal             Petr Cech   35       GK             4           7.0
# Arsenal          Theo Walcott   28       RW             1          20.0
# Arsenal     Laurent Koscielny   31       CB             3          22.0
# ...                       ...  ...      ...           ...           ...
# West+Ham  Edimilson Fernandes   21       CM             2           5.0
# West+Ham       Arthur Masuaku   23       LB             3           7.0
# West+Ham            Sam Byram   23       RB             3           4.5
# West+Ham      Ashley Fletcher   21       CF             1           1.0
# West+Ham         Diafra Sakho   27       CF             1          10.0
#
#           page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# club
# ...

# %%
players.sort_values(['club','market_value'],ascending=[True,False])
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 31   Alexandre Lacazette   Arsenal   26       CF             1          40.0
# 10          Granit Xhaka   Arsenal   24       DM             2          35.0
# 11          Granit Xhaka   Arsenal   24       DM             2          35.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 451      Darren Randolph  West+Ham   30       GK             4           2.5
# 452        James Collins  West+Ham   33       CB             3           2.0
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
#
# ...

# %%
players[players.duplicated()]
# Out:
#                        name     club  age position  position_cat  \
# 11             Granit Xhaka  Arsenal   24       DM             2
# 13  Alex Oxlade-Chamberlain  Arsenal   23       RM             2
# 23  Alex Oxlade-Chamberlain  Arsenal   23       RM             2
#
#     market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 11          35.0        1815        5.5   2.00%          85       2
# 13          22.0        1519        6.0   1.80%          83       1
# 23          22.0        1519        6.0   1.80%          83       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 11  Switzerland            0        2        1         1            0
# 13      England            0        2        1         1            0
# 23      England            0        2        1         1            0

# %%
players.loc[players.duplicated(['club','age','position','market_value'] , keep=False)]
# Out:
#                         name               club  age position  position_cat  \
# 10              Granit Xhaka            Arsenal   24       DM             2
# 11              Granit Xhaka            Arsenal   24       DM             2
# 12   Alex Oxlade-Chamberlain            Arsenal   23       RM             2
# 13   Alex Oxlade-Chamberlain            Arsenal   23       RM             2
# 23   Alex Oxlade-Chamberlain            Arsenal   23       RM             2
# 58                Lewis Dunk  Brighton+and+Hove   25       CB             3
# 59               Shane Duffy  Brighton+and+Hove   25       CB             3
# 253              Fernandinho    Manchester+City   32       DM             2
# 260                 Fernando    Manchester+City   32       DM             2
# 273              Marcos Rojo  Manchester+United   27       CB             3
# 279           Chris Smalling  Manchester+United   27       CB             3
# ...

# %%
players.drop_duplicates(keep='first')
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
players[players.duplicated()]
# Out:
#                        name     club  age position  position_cat  \
# 11             Granit Xhaka  Arsenal   24       DM             2
# 13  Alex Oxlade-Chamberlain  Arsenal   23       RM             2
# 23  Alex Oxlade-Chamberlain  Arsenal   23       RM             2
#
#     market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 11          35.0        1815        5.5   2.00%          85       2
# 13          22.0        1519        6.0   1.80%          83       1
# 23          22.0        1519        6.0   1.80%          83       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 11  Switzerland            0        2        1         1            0
# 13      England            0        2        1         1            0
# 23      England            0        2        1         1            0

# %%
players.drop(19,axis=0)
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
players.drop(index=[2,3,4,5])
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 6         Olivier Giroud   Arsenal   30       CF             1          22.0
# 7          Nacho Monreal   Arsenal   31       LB             3          13.0
# 8       Shkodran Mustafi   Arsenal   25       CB             3          30.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
players.drop(columns=['age','market_value','club'])
# Out:
#                     name position  position_cat  page_views  fpl_value  \
# 0         Alexis Sanchez       LW             1        4329       12.0
# 1             Mesut Ozil       AM             1        4395        9.5
# 2              Petr Cech       GK             4        1529        5.5
# 3           Theo Walcott       RW             1        2393        7.5
# 4      Laurent Koscielny       CB             3         912        6.0
# ..                   ...      ...           ...         ...        ...
# 460  Edimilson Fernandes       CM             2         288        4.5
# 461       Arthur Masuaku       LB             3         199        4.5
# 462            Sam Byram       RB             3         198        4.5
# 463      Ashley Fletcher       CF             1         412        4.5
# 464         Diafra Sakho       CF             1         214        5.5
#
#     fpl_sel  fpl_points  region     nationality  new_foreign  age_cat  \
# ...

# %%
players.pop('name')
# Out:
# 0           Alexis Sanchez
# 1               Mesut Ozil
# 2                Petr Cech
# 3             Theo Walcott
# 4        Laurent Koscielny
#               ...
# 460    Edimilson Fernandes
# 461         Arthur Masuaku
# 462              Sam Byram
# 463        Ashley Fletcher
# 464           Diafra Sakho
# Name: name, Length: 465, dtype: object

# %%
players = pd.read_csv('C:\download\course softwares\The Ultimate Pandas Bootcamp Advanced Python Data Analysis\python practice files\Sources\soccer.csv')

# %%
players
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
players.isna()
# Out:
#       name   club    age  position  position_cat  market_value  page_views  \
# 0    False  False  False     False         False         False       False
# 1    False  False  False     False         False         False       False
# 2    False  False  False     False         False         False       False
# 3    False  False  False     False         False         False       False
# 4    False  False  False     False         False         False       False
# ..     ...    ...    ...       ...           ...           ...         ...
# 460  False  False  False     False         False         False       False
# 461  False  False  False     False         False         False       False
# 462  False  False  False     False         False         False       False
# 463  False  False  False     False         False         False       False
# 464  False  False  False     False         False         False       False
#
# ...

# %%
np.count_nonzero(players.isna())
# Out:
# 4

# %%
players[players.isna().values]
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24      NaN             2
# 30        Granit Xhaka         Arsenal   24      NaN             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30            NaN        1815        5.5   2.00%          85       2
# 30            NaN        1815        5.5   2.00%          85       2
# 192           NaN          56        6.0   0.60%           0       2
# 195           NaN        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 30   Switzerland            0        2        1         1            0
# ...

# %%
players[players.isna().values].drop_duplicates()
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24      NaN             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30            NaN        1815        5.5   2.00%          85       2
# 192           NaN          56        6.0   0.60%           0       2
# 195           NaN        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0

# %%
players.fillna('value').loc[[30,192,195]]
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24    value             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#     market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30         value        1815        5.5   2.00%          85       2
# 192        value          56        6.0   0.60%           0       2
# 195        value        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0

# %%
players.fillna({'market_value':100,'position':'PM'}).loc[[30,192,195]]
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24       PM             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30          100.0        1815        5.5   2.00%          85       2
# 192         100.0          56        6.0   0.60%           0       2
# 195         100.0        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0

# %%
players.dropna(axis=1,how='any').loc[[30,192,195]]
# Out:
#                   name            club  age  position_cat  page_views  \
# 30        Granit Xhaka         Arsenal   24             2        1815
# 192       Steve Mounie    Huddersfield   22             1          56
# 195  Kasper Schmeichel  Leicester+City   30             4        1601
#
#      fpl_value fpl_sel  fpl_points  region  nationality  new_foreign  age_cat  \
# 30         5.5   2.00%          85       2  Switzerland            0        2
# 192        6.0   0.60%           0       2        Benin            0        2
# 195        5.0   2.40%         109       2      Denmark            0        4
#
#      club_id  big_club  new_signing
# 30         1         1            0
# 192        8         0            0
# 195        9         0            0

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
df2 = players.drop(index=[2,10,21] ,columns='market_value')

# %%
df2
# Out:
#                     name      club  age position  position_cat  page_views  \
# 0         Alexis Sanchez   Arsenal   28       LW             1        4329
# 1             Mesut Ozil   Arsenal   28       AM             1        4395
# 3           Theo Walcott   Arsenal   28       RW             1        2393
# 4      Laurent Koscielny   Arsenal   31       CB             3         912
# 5        Hector Bellerin   Arsenal   22       RB             3        1675
# ..                   ...       ...  ...      ...           ...         ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2         288
# 461       Arthur Masuaku  West+Ham   23       LB             3         199
# 462            Sam Byram  West+Ham   23       RB             3         198
# 463      Ashley Fletcher  West+Ham   21       CF             1         412
# 464         Diafra Sakho  West+Ham   27       CF             1         214
#
# ...

# %%
df2.nationality.isna().sum()
# Out:
# 0

# %%
df2.nationality.drop_duplicates().size
# Out:
# 61

# %%
df2.nationality.nunique()
# Out:
# 61

# %%
df2.drop_duplicates(['age','club','position'] , keep='first').loc[:,['age','position']]
# Out:
#      age position
# 0     28       LW
# 1     28       AM
# 3     28       RW
# 4     31       CB
# 5     22       RB
# ..   ...      ...
# 460   21       CM
# 461   23       LB
# 462   23       RB
# 463   21       CF
# 464   27       CF
#
# [433 rows x 2 columns]

# %%
players.agg('mean')
# Out:
# age              26.776344
# position_cat      2.178495
# market_value     11.125649
# page_views      771.546237
# fpl_value         5.450538
# fpl_points       57.544086
# region            1.989247
# new_foreign       0.034409
# age_cat           3.195699
# club_id          10.253763
# big_club          0.309677
# new_signing       0.144086
# dtype: float64

# %%
players.agg('min')
# Out:
# name            Aaron Cresswell
# club                    Arsenal
# age                          17
# position_cat                  1
# market_value               0.05
# page_views                    3
# fpl_value                   4.0
# fpl_sel                   0.00%
# fpl_points                    0
# region                        1
# nationality             Algeria
# new_foreign                   0
# age_cat                       1
# club_id                       1
# big_club                      0
# new_signing                   0
# dtype: object

# %%
players.agg(['min','max','mean'])
# Out:
#                     name      club        age  position_cat  market_value  \
# min      Aaron Cresswell   Arsenal  17.000000      1.000000      0.050000
# max   Åukasz FabiaÅ„ski  West+Ham  38.000000      4.000000     75.000000
# mean                 NaN       NaN  26.776344      2.178495     11.125649
#
#        page_views  fpl_value fpl_sel  fpl_points    region nationality  \
# min      3.000000   4.000000   0.00%    0.000000  1.000000     Algeria
# max   7664.000000  12.500000   9.70%  264.000000  4.000000       Wales
# mean   771.546237   5.450538     NaN   57.544086  1.989247         NaN
#
#       new_foreign   age_cat    club_id  big_club  new_signing
# min      0.000000  1.000000   1.000000  0.000000     0.000000
# max      1.000000  6.000000  20.000000  1.000000     1.000000
# mean     0.034409  3.195699  10.253763  0.309677     0.144086

# %%
players.select_dtypes(np.number).agg(['min','max','mean'])
# Out:
#             age  position_cat  market_value   page_views  fpl_value  \
# min   17.000000      1.000000      0.050000     3.000000   4.000000
# max   38.000000      4.000000     75.000000  7664.000000  12.500000
# mean  26.776344      2.178495     11.125649   771.546237   5.450538
#
#       fpl_points    region  new_foreign   age_cat    club_id  big_club  \
# min     0.000000  1.000000     0.000000  1.000000   1.000000  0.000000
# max   264.000000  4.000000     1.000000  6.000000  20.000000  1.000000
# mean   57.544086  1.989247     0.034409  3.195699  10.253763  0.309677
#
#       new_signing
# min      0.000000
# max      1.000000
# mean     0.144086

# %%
def get_popularity(x):
    if x < 220:
        return 'relatively unknown'
    elif x < 600:
        return 'kind of popular'
    elif x < 2000:
        return 'popular'
    else:
        return 'super popular'

# %%
get_popularity(500)
# Out:
# 'kind of popular'

# %%
players.page_views.apply(get_popularity)
# Out:
# 0           super popular
# 1           super popular
# 2                 popular
# 3           super popular
# 4                 popular
#               ...
# 460       kind of popular
# 461    relatively unknown
# 462    relatively unknown
# 463       kind of popular
# 464    relatively unknown
# Name: page_views, Length: 465, dtype: object

# %%
players['popularity'] = players.page_views.apply(get_popularity)

# %%
players['popularity']
# Out:
# 0           super popular
# 1           super popular
# 2                 popular
# 3           super popular
# 4                 popular
#               ...
# 460       kind of popular
# 461    relatively unknown
# 462    relatively unknown
# 463       kind of popular
# 464    relatively unknown
# Name: popularity, Length: 465, dtype: object

# %%
players.popularity.value_counts()
# Out:
# kind of popular       170
# popular               143
# relatively unknown    115
# super popular          37
# Name: popularity, dtype: int64

# %%
players[players.popularity == 'super popular'].name.size
# Out:
# 37

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing     popularity
# ...

# %%
players.loc[3,'position']='CM'

# %%
players
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       CM             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
players.iloc[3,3]='CM'

# %%
players
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       CM             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
players['page_views'][2]=2001
# Out:
# <ipython-input-89-321d99093855>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   players['page_views'][2]=2001

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       CM             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        2001        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing     popularity
# ...

# %%
players.loc[0:3,'position'] = ['CM','RM','GM','PM']

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       CM             1          65.0
# 1         Mesut Ozil  Arsenal   28       RM             1          50.0
# 2          Petr Cech  Arsenal   35       GM             4           7.0
# 3       Theo Walcott  Arsenal   28       PM             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        2001        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing     popularity
# ...

# %%
players.loc[players.name.str.startswith('Aaron')]
# Out:
#                 name          club  age position  position_cat  market_value  \
# 15      Aaron Ramsey       Arsenal   26       CM             2          35.0
# 157     Aaron Lennon       Everton   30       RW             1           5.0
# 176       Aaron Mooy  Huddersfield   26       CM             2           5.0
# 455  Aaron Cresswell      West+Ham   27       LB             3          12.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 15         1040        7.0   5.10%          56       1       Wales
# 157         504        5.5   0.20%          22       1     England
# 176         588        5.5   2.50%           0       4   Australia
# 455         380        5.0   1.30%          60       1     England
#
#      new_foreign  age_cat  club_id  big_club  new_signing       popularity
# 15             0        3        1         1            0          popular
# 157            0        4        7         0            0  kind of popular
# ...

# %%
players.loc[players.name.str.startswith('Aaron'),'name']='Ronny'

# %%
players.loc[[15,157,176,455]]
# Out:
#       name          club  age position  position_cat  market_value  \
# 15   Ronny       Arsenal   26       CM             2          35.0
# 157  Ronny       Everton   30       RW             1           5.0
# 176  Ronny  Huddersfield   26       CM             2           5.0
# 455  Ronny      West+Ham   27       LB             3          12.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 15         1040        7.0   5.10%          56       1       Wales
# 157         504        5.5   0.20%          22       1     England
# 176         588        5.5   2.50%           0       4   Australia
# 455         380        5.0   1.30%          60       1     England
#
#      new_foreign  age_cat  club_id  big_club  new_signing       popularity
# 15             0        3        1         1            0          popular
# 157            0        4        7         0            0  kind of popular
# ...

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       CM             1          65.0
# 1         Mesut Ozil  Arsenal   28       RM             1          50.0
# 2          Petr Cech  Arsenal   35       GM             4           7.0
# 3       Theo Walcott  Arsenal   28       PM             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        2001        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing     popularity
# ...

# %%
df_mini = players.iloc[:4,1:5]

# %%
df_mini
# Out:
#       club  age position  position_cat
# 0  Arsenal   28       CM             1
# 1  Arsenal   28       RM             1
# 2  Arsenal   35       GM             4
# 3  Arsenal   28       PM             1

# %%
player_names = pd.Series(['Bronson','Bradley','Ronald','Ronny'])

# %%
player_names
# Out:
# 0    Bronson
# 1    Bradley
# 2     Ronald
# 3      Ronny
# dtype: object

# %%
df_mini.insert(0,'nicknames',player_names)

# %%
df_mini
# Out:
#   nicknames     club  age position  position_cat
# 0   Bronson  Arsenal   28       CM             1
# 1   Bradley  Arsenal   28       RM             1
# 2    Ronald  Arsenal   35       GM             4
# 3     Ronny  Arsenal   28       PM             1

# %%
df_mini.assign(career_goals=[12,67,179,49] , nationality=['American','British','Turkish','Indian'])
# Out:
#   nicknames     club  age position  position_cat  career_goals nationality
# 0   Bronson  Arsenal   28       CM             1            12    American
# 1   Bradley  Arsenal   28       RM             1            67     British
# 2    Ronald  Arsenal   35       GM             4           179     Turkish
# 3     Ronny  Arsenal   28       PM             1            49      Indian

# %%
df_mini
# Out:
#   nicknames     club  age position  position_cat
# 0   Bronson  Arsenal   28       CM             1
# 1   Bradley  Arsenal   28       RM             1
# 2    Ronald  Arsenal   35       GM             4
# 3     Ronny  Arsenal   28       PM             1

# %%
cristiano = pd.Series({'nicknames':'Cristiano','age':32,'club':'Juventus','position':'RW','position_cat':3},name=4)

# %%
cristiano
# Out:
# nicknames       Cristiano
# age                    32
# club             Juventus
# position               RW
# position_cat            3
# Name: 4, dtype: object

# %%
df_mini.append(cristiano)
# Out:
#    nicknames      club  age position  position_cat
# 0    Bronson   Arsenal   28       CM             1
# 1    Bradley   Arsenal   28       RM             1
# 2     Ronald   Arsenal   35       GM             4
# 3      Ronny   Arsenal   28       PM             1
# 4  Cristiano  Juventus   32       RW             3

# %%
other_players = pd.DataFrame({'nicknames':['Gianlugi','Leonal'] , 'age':[37,42], 'club':['Juventus','Barcelona'] ,
                              'position':['GM','PM'] , 'position_cat':[2,4] } ,index = [5,6])

# %%
other_players
# Out:
#   nicknames  age       club position  position_cat
# 5  Gianlugi   37   Juventus       GM             2
# 6    Leonal   42  Barcelona       PM             4

# %%
df_mini.append(other_players)
# Out:
#   nicknames       club  age position  position_cat
# 0   Bronson    Arsenal   28       CM             1
# 1   Bradley    Arsenal   28       RM             1
# 2    Ronald    Arsenal   35       GM             4
# 3     Ronny    Arsenal   28       PM             1
# 5  Gianlugi   Juventus   37       GM             2
# 6    Leonal  Barcelona   42       PM             4

# %%
df_random = players.sample(4).sample(4,axis=1)

# %%
df_random
# Out:
#      new_signing  age  market_value  age_cat
# 455            0   27          12.0        3
# 208            0   28           3.0        4
# 4              0   31          22.0        4
# 143            0   34           2.0        6

# %%
add = pd.Series({'nationality':'Norway','new_foreign':2,'big_club':1,'region':3},name=306)

# %%
df_random.append(add)
# Out:
#      new_signing   age  market_value  age_cat  big_club nationality  \
# 455          0.0  27.0          12.0      3.0       NaN         NaN
# 208          0.0  28.0           3.0      4.0       NaN         NaN
# 4            0.0  31.0          22.0      4.0       NaN         NaN
# 143          0.0  34.0           2.0      6.0       NaN         NaN
# 306          NaN   NaN           NaN      NaN       1.0      Norway
#
#      new_foreign  region
# 455          NaN     NaN
# 208          NaN     NaN
# 4            NaN     NaN
# 143          NaN     NaN
# 306          2.0     3.0

# %%
df_random.assign(years_in_league=[3,5,7,9])
# Out:
#      new_signing  age  market_value  age_cat  years_in_league
# 455            0   27          12.0        3                3
# 208            0   28           3.0        4                5
# 4              0   31          22.0        4                7
# 143            0   34           2.0        6                9
