# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('C:\download\course softwares\DATASETS\Google playstore apps\Google Playstore Apps.csv')
# Out:
#      Rank                               Name  \
# 0       1        Meesho: Online Shopping App
# 1       2            Shopee: Online Shopping
# 2       3                          Instagram
# 3       4     MX Player: Videos, OTT & Games
# 4       5                           speedfiy
# ..    ...                                ...
# 595   596                          Cutie SMS
# 596   597  MV Master - MV Master video maker
# 597   598            Amazon Pay For Business
# 598   599          Music Player - MP3 Player
# 599   600         Safe CleanUp - Boost phone
#
#                               Developer                 Category    Size  \
# 0                                Meesho                 Shopping   15 MB
# 1                                Shopee                 Shopping   68 MB
# 2                             Instagram                   Social   41 MB
# 3    MX Media (formerly J2 Interactive)  Video Players & Editors   36 MB
# ...

# %%
pd.read_csv('C:\download\course softwares\DATASETS\Google playstore apps\Google Playstore Apps.csv',usecols=['Name','Star Rating'])
# Out:
#                                   Name  Star Rating
# 0          Meesho: Online Shopping App          4.4
# 1              Shopee: Online Shopping          4.1
# 2                            Instagram          4.3
# 3       MX Player: Videos, OTT & Games          4.1
# 4                             speedfiy          4.5
# ..                                 ...          ...
# 595                          Cutie SMS          4.9
# 596  MV Master - MV Master video maker          3.6
# 597            Amazon Pay For Business          4.3
# 598          Music Player - MP3 Player          4.6
# 599         Safe CleanUp - Boost phone          4.0
#
# [600 rows x 2 columns]

# %%
pd.read_csv('C:\download\course softwares\DATASETS\Google playstore apps\Google Playstore Apps.csv',usecols=['Name','Star Rating']
           ,index_col='Name')
# Out:
#                                    Star Rating
# Name
# Meesho: Online Shopping App                4.4
# Shopee: Online Shopping                    4.1
# Instagram                                  4.3
# MX Player: Videos, OTT & Games             4.1
# speedfiy                                   4.5
# ...                                        ...
# Cutie SMS                                  4.9
# MV Master - MV Master video maker          3.6
# Amazon Pay For Business                    4.3
# Music Player - MP3 Player                  4.6
# Safe CleanUp - Boost phone                 4.0
#
# [600 rows x 1 columns]

# %%
apps = pd.read_csv('C:\download\course softwares\DATASETS\Google playstore apps\Google Playstore Apps.csv',usecols=['Name','Star Rating']
           ,index_col='Name')

# %%
apps
# Out:
#                                    Star Rating
# Name
# Meesho: Online Shopping App                4.4
# Shopee: Online Shopping                    4.1
# Instagram                                  4.3
# MX Player: Videos, OTT & Games             4.1
# speedfiy                                   4.5
# ...                                        ...
# Cutie SMS                                  4.9
# MV Master - MV Master video maker          3.6
# Amazon Pay For Business                    4.3
# Music Player - MP3 Player                  4.6
# Safe CleanUp - Boost phone                 4.0
#
# [600 rows x 1 columns]

# %%
apps = pd.read_csv('C:\download\course softwares\DATASETS\Google playstore apps\Google Playstore Apps.csv',usecols=['Name','Star Rating']
           ,index_col='Name',squeeze=True)

# %%
apps.head()
# Out:
# Name
# Meesho: Online Shopping App       4.4
# Shopee: Online Shopping           4.1
# Instagram                         4.3
# MX Player: Videos, OTT & Games    4.1
# speedfiy                          4.5
# Name: Star Rating, dtype: float64

# %%
apps.size
# Out:
# 600

# %%
apps.values
# Out:
# array([4.4, 4.1, 4.3, 4.1, 4.5, 4.2, 4. , 4.3, 4.3, 3.8, 4.3, 4.1, 4.3,
#        4.3, 4.3, 4.3, 4. , 4.2, 4.3, 4.5, 4.3, 4.6, 4.2, 4.1, 4.2, 4.2,
#        4.4, 3.5, 4.2, 4.5, 4.1, 3.5, 4.3, 4.4, 4.3, 3.5, 4.1, 4.2, 4.3,
#        4.3, 4. , 4.3, 4.2, 3. , 4.3, 4.4, 3.9, 4.2, 4.1, 4.1, 4. , 3.7,
#        3.8, 4.3, 4.3, 4.3, 4.6, 3.7, 4.6, 4.1, 4.3, 4.2, 4.4, 4.4, 4.2,
#        4. , 4.1, 4. , 4.5, 3.5, 4.5, 4.1, 4.2, 4.5, 4.1, 4.1, 4.4, 4.2,
#        4.6, 4.3, 4.1, 4.5, 4.2, 4.3, 3.8, 4.3, 4.1, 4.1, 4. , 4.3, 4.4,
#        3.6, 3.7, 3.7, 3.8, 4.6, 4.5, 4. , 4.3, 4.3, 4.7, 4.3, 4.3, 3.4,
#        3.4, 4.1, 4. , 4.5, 3.1, 4.4, 4.5, 3.7, 4.5, 4.7, 3.8, 4.3, 4.3,
#        4.2, 4.2, 4.3, 4.3, 4.4, 4. , 4.4, 4. , 4.4, 3.9, 4.2, 3.7, 3.4,
#        4.4, 4. , 4.2, 4.4, 4.3, 4.2, 4. , 4. , 4.3, 3. , 4.1, 4.4, 4.4,
#        4.6, 4.6, 4.4, 3.7, 4.7, 4.4, 4.1, 3.5, 4.1, 4. , 3.9, 4.1, 3.9,
#        3.9, 3.7, 4.3, 3.9, 4.3, 4.3, 4.2, 4.1, 3.4, 4.3, 4.6, 4.1, 4.4,
# ...

# %%
apps.index
# Out:
# Index(['Meesho: Online Shopping App', 'Shopee: Online Shopping', 'Instagram',
#        'MX Player: Videos, OTT & Games', 'speedfiy', 'Snapchat',
#        'ZOOM Cloud Meetings', 'Flipkart Online Shopping App', 'Telegram',
#        'Chingari - powered by GARI',
#        ...
#        'Cast to TV & Screen Mirroring', 'HD Camera',
#        'Share: File Transfer, Share it', 'LimeRoad Shop Curated Fashion',
#        'Talking Tom Cat 2', 'Cutie SMS', 'MV Master - MV Master video maker',
#        'Amazon Pay For Business', 'Music Player - MP3 Player',
#        'Safe CleanUp - Boost phone'],
#       dtype='object', name='Name', length=600)

# %%
len(apps)
# Out:
# 600

# %%
apps.nunique()
# Out:
# 23

# %%
apps.nunique(dropna=False)
# Out:
# 24

# %%
apps.count()
# Out:
# 599

# %%
apps[apps.isnull()].index
# Out:
# Index(['EasyShare – Ultrafast File Transfer, Free & No Ads'], dtype='object', name='Name')

# %%
apps.isnull().sum()
# Out:
# 1

# %%
list(apps[apps.isnull()].index)
# Out:
# ['EasyShare – Ultrafast File Transfer, Free & No Ads']

# %%
apps.notnull()
# Out:
# Name
# Meesho: Online Shopping App          True
# Shopee: Online Shopping              True
# Instagram                            True
# MX Player: Videos, OTT & Games       True
# speedfiy                             True
#                                      ...
# Cutie SMS                            True
# MV Master - MV Master video maker    True
# Amazon Pay For Business              True
# Music Player - MP3 Player            True
# Safe CleanUp - Boost phone           True
# Name: Star Rating, Length: 600, dtype: bool

# %%
apps[apps.notnull()]
# Out:
# Name
# Meesho: Online Shopping App          4.4
# Shopee: Online Shopping              4.1
# Instagram                            4.3
# MX Player: Videos, OTT & Games       4.1
# speedfiy                             4.5
#                                     ...
# Cutie SMS                            4.9
# MV Master - MV Master video maker    3.6
# Amazon Pay For Business              4.3
# Music Player - MP3 Player            4.6
# Safe CleanUp - Boost phone           4.0
# Name: Star Rating, Length: 599, dtype: float64

# %%
apps_ratings = apps[apps.notnull()]

# %%
apps_ratings
# Out:
# Name
# Meesho: Online Shopping App          4.4
# Shopee: Online Shopping              4.1
# Instagram                            4.3
# MX Player: Videos, OTT & Games       4.1
# speedfiy                             4.5
#                                     ...
# Cutie SMS                            4.9
# MV Master - MV Master video maker    3.6
# Amazon Pay For Business              4.3
# Music Player - MP3 Player            4.6
# Safe CleanUp - Boost phone           4.0
# Name: Star Rating, Length: 599, dtype: float64

# %%
apps_ratings.sum()
# Out:
# 2489.7

# %%
apps_ratings[apps_ratings<4]
# Out:
# Name
# Chingari - powered by GARI                           3.8
# FacePlay - Face Swap Video                           3.5
# ZEE5:Movies, Web Series & more                       3.5
# Translate All- Easy Translator                       3.5
# Mivita - Face Swap Video Maker                       3.0
#                                                     ...
# GB What's Version 2021 App                           3.9
# Star Live Sports TV Cricket HD                       3.2
# WeLive: Live Video Chat & Make Friends               3.8
# FFF FF Skin Tool, Elite Pass Bundles, Emote, Skin    3.9
# MV Master - MV Master video maker                    3.6
# Name: Star Rating, Length: 126, dtype: float64

# %%
apps_ratings[apps_ratings<4].sum()
# Out:
# 456.0999999999999

# %%
apps.dropna()
# Out:
# Name
# Meesho: Online Shopping App          4.4
# Shopee: Online Shopping              4.1
# Instagram                            4.3
# MX Player: Videos, OTT & Games       4.1
# speedfiy                             4.5
#                                     ...
# Cutie SMS                            4.9
# MV Master - MV Master video maker    3.6
# Amazon Pay For Business              4.3
# Music Player - MP3 Player            4.6
# Safe CleanUp - Boost phone           4.0
# Name: Star Rating, Length: 599, dtype: float64

# %%
apps.fillna(1)
# Out:
# Name
# Meesho: Online Shopping App          4.4
# Shopee: Online Shopping              4.1
# Instagram                            4.3
# MX Player: Videos, OTT & Games       4.1
# speedfiy                             4.5
#                                     ...
# Cutie SMS                            4.9
# MV Master - MV Master video maker    3.6
# Amazon Pay For Business              4.3
# Music Player - MP3 Player            4.6
# Safe CleanUp - Boost phone           4.0
# Name: Star Rating, Length: 600, dtype: float64

# %%
apps.sum()
# Out:
# 2489.7

# %%
apps.count()
# Out:
# 599

# %%
apps.mean()
# Out:
# 4.15642737896494

# %%
apps.median()
# Out:
# 4.2

# %%
apps.min()
# Out:
# 2.1

# %%
apps.std()
# Out:
# 0.3628960864354173

# %%
apps.var()
# Out:
# 0.13169356955014186

# %%
apps.describe()
# Out:
# count    599.000000
# mean       4.156427
# std        0.362896
# min        2.100000
# 25%        4.000000
# 50%        4.200000
# 75%        4.400000
# max        4.900000
# Name: Star Rating, dtype: float64

# %%
apps.mode()
# Out:
# 0    4.3
# dtype: float64

# %%
apps.value_counts()
# Out:
# 4.3    111
# 4.1     72
# 4.4     62
# 4.2     61
# 4.5     57
# 4.0     55
# 4.6     37
# 3.9     35
# 3.8     25
# 3.7     17
# 3.6     11
# 4.7     11
# 3.5     10
# 3.4      9
# 4.8      6
# 3.1      5
# 3.3      4
# 3.0      3
# 2.8      2
# 3.2      2
# 2.1      2
# 4.9      1
# 2.6      1
# Name: Star Rating, dtype: int64

# %%
apps.value_counts().iloc[0]
# Out:
# 111

# %%
apps.idxmax()
# Out:
# 'Cutie SMS'

# %%
apps[apps == apps.max()]
# Out:
# Name
# Cutie SMS    4.9
# Name: Star Rating, dtype: float64

# %%
apps.idxmin()
# Out:
# 'HD Video Screen Mirroring'

# %%
apps[apps == apps.min()]
# Out:
# Name
# HD Video Screen Mirroring         2.1
# HD Video Screen Mirroring Cast    2.1
# Name: Star Rating, dtype: float64

# %%
apps.sort_values()
# Out:
# Name
# HD Video Screen Mirroring Cast                        2.1
# HD Video Screen Mirroring                             2.1
# Mylab CoviSelf                                        2.6
# Live Cricket TV - HD Live Cricket 2021                2.8
# Co-WIN Vaccinator App                                 2.8
#                                                      ...
# TocToc - live video chat                              4.8
# Image to PDF Converter - JPG to PDF, PDF Maker        4.8
# Home Workout - No Equipment                           4.8
# Cutie SMS                                             4.9
# EasyShare – Ultrafast File Transfer, Free & No Ads    NaN
# Name: Star Rating, Length: 600, dtype: float64

# %%
apps.sort_values(ascending=False)
# Out:
# Name
# Cutie SMS                                             4.9
# Image to PDF Converter - JPG to PDF, PDF Maker        4.8
# Home Workout - No Equipment                           4.8
# Six Pack in 30 Days                                   4.8
# TocToc - live video chat                              4.8
#                                                      ...
# Live Cricket TV - HD Live Cricket 2021                2.8
# Mylab CoviSelf                                        2.6
# HD Video Screen Mirroring                             2.1
# HD Video Screen Mirroring Cast                        2.1
# EasyShare – Ultrafast File Transfer, Free & No Ads    NaN
# Name: Star Rating, Length: 600, dtype: float64

# %%
apps.nsmallest(20)
# Out:
# Name
# HD Video Screen Mirroring                 2.1
# HD Video Screen Mirroring Cast            2.1
# Mylab CoviSelf                            2.6
# Co-WIN Vaccinator App                     2.8
# Live Cricket TV - HD Live Cricket 2021    2.8
# Mivita - Face Swap Video Maker            3.0
# HD Video Projector Simulator              3.0
# Tinder - Match. Chat. Date. Your Way.     3.0
# Shield VPN - Private VPN Proxy            3.1
# Skymize Skins                             3.1
# Big Bazaar - Making India Beautiful       3.1
# FileBin - Pic & Video Recovery            3.1
# Shining wallpaper,4K HD                   3.1
# Koalo Speed                               3.2
# Star Live Sports TV Cricket HD            3.2
# Screen Mirrroring HD Video                3.3
# Bharat Option - Trading online            3.3
# Mobile Rupee                              3.3
# ShopClues: Online Shopping App            3.3
# mAadhaar                                  3.4
# ...

# %%
apps.nlargest(20)
# Out:
# Name
# Cutie SMS                                             4.9
# Image to PDF Converter - JPG to PDF, PDF Maker        4.8
# Collage Maker | Photo Editor                          4.8
# Sri Mandir - Your Own Temple                          4.8
# Home Workout - No Equipment                           4.8
# Six Pack in 30 Days                                   4.8
# TocToc - live video chat                              4.8
# Video downloader for Instagram                        4.7
# India's largest Community app - Kutumb                4.7
# OKEN - CamScanner, PDF scanner                        4.7
# Headfone - Audio Stories & Podcasts                   4.7
# QR Code Scanner & Scanner App                         4.7
# India AI Credit Cash loan app                         4.7
# Bikayi: Whatsapp Catalogue and Make Business Easy     4.7
# CRED: Credit Card Bills & More                        4.7
# Music Player - MP3 Player, Play Music                 4.7
# ...

# %%
apps.sort_index()
# Out:
# Name
# 1 Minute Me Aadhar Loan - आधार कार्ड पे लोन गाइड      4.5
# 1.1.1.1: Faster & Safer Internet                      4.0
# 1DM: Adblock Browser, Video & Torrent Downloader      4.4
# 2022 Calendar                                         4.5
# 5paisa: Stocks, Share Market Trading App, NSE, BSE    4.2
#                                                      ...
# vFlat Scan - PDF Scanner, OCR                         4.5
# what3words                                            3.9
# µTorrent® - Torrent Downloader                        4.4
# अपने नाम की रिंगटोन बनाए - Name Ringtone Maker        4.0
# गाय भैंस wala पशुमेला - Animall app                   4.5
# Name: Star Rating, Length: 600, dtype: float64

# %%
apps.sort_index(ascending=False)
# Out:
# Name
# गाय भैंस wala पशुमेला - Animall app                   4.5
# अपने नाम की रिंगटोन बनाए - Name Ringtone Maker        4.0
# µTorrent® - Torrent Downloader                        4.4
# what3words                                            3.9
# vFlat Scan - PDF Scanner, OCR                         4.5
#                                                      ...
# 5paisa: Stocks, Share Market Trading App, NSE, BSE    4.2
# 2022 Calendar                                         4.5
# 1DM: Adblock Browser, Video & Torrent Downloader      4.4
# 1.1.1.1: Faster & Safer Internet                      4.0
# 1 Minute Me Aadhar Loan - आधार कार्ड पे लोन गाइड      4.5
# Name: Star Rating, Length: 600, dtype: float64

# %%
apps.head()
# Out:
# Name
# Meesho: Online Shopping App       4.4
# Shopee: Online Shopping           4.1
# Instagram                         4.3
# MX Player: Videos, OTT & Games    4.1
# speedfiy                          4.5
# Name: Star Rating, dtype: float64

# %%
four_plus =  apps[apps>4]

# %%
four_plus
# Out:
# Name
# Meesho: Online Shopping App       4.4
# Shopee: Online Shopping           4.1
# Instagram                         4.3
# MX Player: Videos, OTT & Games    4.1
# speedfiy                          4.5
#                                  ...
# LimeRoad Shop Curated Fashion     4.1
# Talking Tom Cat 2                 4.1
# Cutie SMS                         4.9
# Amazon Pay For Business           4.3
# Music Player - MP3 Player         4.6
# Name: Star Rating, Length: 418, dtype: float64

# %%
four_plus.nsmallest(20)
# Out:
# Name
# Shopee: Online Shopping                               4.1
# MX Player: Videos, OTT & Games                        4.1
# Google Meet                                           4.1
# WhatsApp Messenger                                    4.1
# Josh: Short Videos App                                4.1
# ShareChat - Made in India                             4.1
# MX TakaTak Short Video App                            4.1
# Junk Smasher - Phone Cleaner                          4.1
# EPIK - Photo Editor                                   4.1
# DealShare - Online Grocery App                        4.1
# Swift Booster - Smart Cleaner                         4.1
# Zomato - Online Food Delivery & Restaurant Reviews    4.1
# Vast VPN - Secure VPN Proxy                           4.1
# Vido : Lyrical Video Status Maker                     4.1
# X Sender Share: File Transfer                         4.1
# SonyLIV:Entertainment & Sports                        4.1
# ...

# %%
four_plus.nsmallest(20).mean()
# Out:
# 4.1

# %%
four_plus.nsmallest(20).median()
# Out:
# 4.1

# %%
four_plus.nsmallest(20).std()
# Out:
# 0.0

# %%
apps.head()
# Out:
# Name
# Meesho: Online Shopping App       4.4
# Shopee: Online Shopping           4.1
# Instagram                         4.3
# MX Player: Videos, OTT & Games    4.1
# speedfiy                          4.5
# Name: Star Rating, dtype: float64

# %%
more_apps = pd.Series({'PUBG':4.5,'Urle':4.1,'Tiktok':4.2,'Kendra':4.1})

# %%
apps.add(more_apps,fill_value=0)
# Out:
# 1 Minute Me Aadhar Loan - आधार कार्ड पे लोन गाइड      4.5
# 1.1.1.1: Faster & Safer Internet                      4.0
# 1DM: Adblock Browser, Video & Torrent Downloader      4.4
# 2022 Calendar                                         4.5
# 5paisa: Stocks, Share Market Trading App, NSE, BSE    4.2
#                                                      ...
# vFlat Scan - PDF Scanner, OCR                         4.5
# what3words                                            3.9
# µTorrent® - Torrent Downloader                        4.4
# अपने नाम की रिंगटोन बनाए - Name Ringtone Maker        4.0
# गाय भैंस wala पशुमेला - Animall app                   4.5
# Length: 604, dtype: float64

# %%
apps.var()
# Out:
# 0.13169356955014186

# %%
apps.std()
# Out:
# 0.3628960864354173

# %%
apps.cumsum()
# Out:
# Name
# Meesho: Online Shopping App             4.4
# Shopee: Online Shopping                 8.5
# Instagram                              12.8
# MX Player: Videos, OTT & Games         16.9
# speedfiy                               21.4
#                                       ...
# Cutie SMS                            2473.2
# MV Master - MV Master video maker    2476.8
# Amazon Pay For Business              2481.1
# Music Player - MP3 Player            2485.7
# Safe CleanUp - Boost phone           2489.7
# Name: Star Rating, Length: 600, dtype: float64

# %%
apps.cumprod()
# Out:
# Name
# Meesho: Online Shopping App             4.4000
# Shopee: Online Shopping                18.0400
# Instagram                              77.5720
# MX Player: Videos, OTT & Games        318.0452
# speedfiy                             1431.2034
#                                        ...
# Cutie SMS                                  inf
# MV Master - MV Master video maker          inf
# Amazon Pay For Business                    inf
# Music Player - MP3 Player                  inf
# Safe CleanUp - Boost phone                 inf
# Name: Star Rating, Length: 600, dtype: float64

# %%
apps.cummin()
# Out:
# Name
# Meesho: Online Shopping App          4.4
# Shopee: Online Shopping              4.1
# Instagram                            4.1
# MX Player: Videos, OTT & Games       4.1
# speedfiy                             4.1
#                                     ...
# Cutie SMS                            2.1
# MV Master - MV Master video maker    2.1
# Amazon Pay For Business              2.1
# Music Player - MP3 Player            2.1
# Safe CleanUp - Boost phone           2.1
# Name: Star Rating, Length: 600, dtype: float64

# %%
apps.cummax()
# Out:
# Name
# Meesho: Online Shopping App          4.4
# Shopee: Online Shopping              4.4
# Instagram                            4.4
# MX Player: Videos, OTT & Games       4.4
# speedfiy                             4.5
#                                     ...
# Cutie SMS                            4.9
# MV Master - MV Master video maker    4.9
# Amazon Pay For Business              4.9
# Music Player - MP3 Player            4.9
# Safe CleanUp - Boost phone           4.9
# Name: Star Rating, Length: 600, dtype: float64

# %%
apps.head()
# Out:
# Name
# Meesho: Online Shopping App       4.4
# Shopee: Online Shopping           4.1
# Instagram                         4.3
# MX Player: Videos, OTT & Games    4.1
# speedfiy                          4.5
# Name: Star Rating, dtype: float64

# %%
apps.diff().head()
# Out:
# Name
# Meesho: Online Shopping App       NaN
# Shopee: Online Shopping          -0.3
# Instagram                         0.2
# MX Player: Videos, OTT & Games   -0.2
# speedfiy                          0.4
# Name: Star Rating, dtype: float64

# %%
mini_apps = apps[:10]

# %%
mini_apps
# Out:
# Name
# Meesho: Online Shopping App       4.4
# Shopee: Online Shopping           4.1
# Instagram                         4.3
# MX Player: Videos, OTT & Games    4.1
# speedfiy                          4.5
# Snapchat                          4.2
# ZOOM Cloud Meetings               4.0
# Flipkart Online Shopping App      4.3
# Telegram                          4.3
# Chingari - powered by GARI        3.8
# Name: Star Rating, dtype: float64

# %%
for i in mini_apps:
    print(i)
# Out:
# 4.4
# 4.1
# 4.3
# 4.1
# 4.5
# 4.2
# 4.0
# 4.3
# 4.3
# 3.8

# %%
for i in mini_apps.index:
    print(i)
# Out:
# Meesho: Online Shopping App
# Shopee: Online Shopping
# Instagram
# MX Player: Videos, OTT & Games
# speedfiy
# Snapchat
# ZOOM Cloud Meetings
# Flipkart Online Shopping App
# Telegram
# Chingari - powered by GARI

# %%
for i in mini_apps.items():
    print(i)
# Out:
# ('Meesho: Online Shopping App', 4.4)
# ('Shopee: Online Shopping', 4.1)
# ('Instagram', 4.3)
# ('MX Player: Videos, OTT & Games', 4.1)
# ('speedfiy', 4.5)
# ('Snapchat', 4.2)
# ('ZOOM Cloud Meetings', 4.0)
# ('Flipkart Online Shopping App', 4.3)
# ('Telegram', 4.3)
# ('Chingari - powered by GARI', 3.8)

# %%
apps.filter(regex='^P')
# Out:
# Name
# PhonePe: UPI, Recharge, Investment, Insurance         4.3
# Paytm -UPI, Money Transfer, Recharge, Bill Payment    4.6
# Pocket FM: Audiobook & Podcast                        4.2
# PLAYit-All in One Video Player                        4.5
# Public - Indian Local Videos                          4.3
# Picsart Photo and Video Editor                        4.2
# Pratilipi - World of Stories                          4.5
# PDF Reader - PDF Viewer                               4.5
# PhonePe Business                                      4.4
# Photo Editor Pro                                      4.6
# PDF Viewer - PDF Reader                               4.6
# Pinterest                                             4.4
# Photo Video Maker                                     4.3
# Photo Lab Picture Editor & Art                        4.0
# PublicVibe - Local Videos from your Locality          4.3
# Powerful Cleaner                                      4.2
# ...

# %%
apps.filter(like='ce')
# Out:
# Name
# PhonePe: UPI, Recharge, Investment, Insurance         4.3
# Facebook                                              4.0
# FacePlay - Face Swap Video                            3.5
# Mivita - Face Swap Video Maker                        3.0
# Facebook Lite                                         3.9
# DealShare - Online Grocery App                        4.1
# Voice Access                                          3.7
# Navi: Loans & Health Insurance                        3.8
# Zepto: 10-Min Grocery Delivery                        4.3
# iFace: AI Cartoon Photo Editor                        3.9
# WPS Office-PDF,Word,Excel,PPT                         4.5
# Remini - AI Photo Enhancer                            4.4
# FRAAZO - Grocery Shopping App                         4.3
# slice: Credit Card Challenger                         4.5
# Yalla - Group Voice Chat Rooms                        4.1
# Document Reader: PDF, Word, Excel, All Office File    4.0
# ...

# %%
apps[apps>4]
# Out:
# Name
# Meesho: Online Shopping App       4.4
# Shopee: Online Shopping           4.1
# Instagram                         4.3
# MX Player: Videos, OTT & Games    4.1
# speedfiy                          4.5
#                                  ...
# LimeRoad Shop Curated Fashion     4.1
# Talking Tom Cat 2                 4.1
# Cutie SMS                         4.9
# Amazon Pay For Business           4.3
# Music Player - MP3 Player         4.6
# Name: Star Rating, Length: 418, dtype: float64

# %%
def gt4(x):
    return x>4;

# %%
apps[gt4]
# Out:
# Name
# Meesho: Online Shopping App       4.4
# Shopee: Online Shopping           4.1
# Instagram                         4.3
# MX Player: Videos, OTT & Games    4.1
# speedfiy                          4.5
#                                  ...
# LimeRoad Shop Curated Fashion     4.1
# Talking Tom Cat 2                 4.1
# Cutie SMS                         4.9
# Amazon Pay For Business           4.3
# Music Player - MP3 Player         4.6
# Name: Star Rating, Length: 418, dtype: float64

# %%
apps.where(lambda x:x>4).dropna()
# Out:
# Name
# Meesho: Online Shopping App       4.4
# Shopee: Online Shopping           4.1
# Instagram                         4.3
# MX Player: Videos, OTT & Games    4.1
# speedfiy                          4.5
#                                  ...
# LimeRoad Shop Curated Fashion     4.1
# Talking Tom Cat 2                 4.1
# Cutie SMS                         4.9
# Amazon Pay For Business           4.3
# Music Player - MP3 Player         4.6
# Name: Star Rating, Length: 418, dtype: float64

# %%
apps.where(lambda x:x<=4).dropna()
# Out:
# Name
# ZOOM Cloud Meetings                                  4.0
# Chingari - powered by GARI                           3.8
# Facebook                                             4.0
# FacePlay - Face Swap Video                           3.5
# ZEE5:Movies, Web Series & more                       3.5
#                                                     ...
# FFF FF Skin Tool, Elite Pass Bundles, Emote, Skin    3.9
# Cast to TV & Screen Mirroring                        4.0
# HD Camera                                            4.0
# MV Master - MV Master video maker                    3.6
# Safe CleanUp - Boost phone                           4.0
# Name: Star Rating, Length: 181, dtype: float64

# %%
apps.mask(lambda x:x>4).dropna()
# Out:
# Name
# ZOOM Cloud Meetings                                  4.0
# Chingari - powered by GARI                           3.8
# Facebook                                             4.0
# FacePlay - Face Swap Video                           3.5
# ZEE5:Movies, Web Series & more                       3.5
#                                                     ...
# FFF FF Skin Tool, Elite Pass Bundles, Emote, Skin    3.9
# Cast to TV & Screen Mirroring                        4.0
# HD Camera                                            4.0
# MV Master - MV Master video maker                    3.6
# Safe CleanUp - Boost phone                           4.0
# Name: Star Rating, Length: 181, dtype: float64

# %%
apps.head()
# Out:
# Name
# Meesho: Online Shopping App       4.4
# Shopee: Online Shopping           4.1
# Instagram                         4.3
# MX Player: Videos, OTT & Games    4.1
# speedfiy                          4.5
# Name: Star Rating, dtype: float64

# %%
apps.loc['Instagram']=4.7
apps.loc['MX Player: Videos, OTT & Games']=4.2
apps.loc['speedfiy']=4.6

# %%
apps.head()
# Out:
# Name
# Meesho: Online Shopping App       4.4
# Shopee: Online Shopping           4.1
# Instagram                         4.7
# MX Player: Videos, OTT & Games    4.2
# speedfiy                          4.6
# Name: Star Rating, dtype: float64

# %%
apps.update(pd.Series([4.5,4.4],index=['Instagram','speedfiy']))

# %%
apps.head()
# Out:
# Name
# Meesho: Online Shopping App       4.4
# Shopee: Online Shopping           4.1
# Instagram                         4.5
# MX Player: Videos, OTT & Games    4.2
# speedfiy                          4.4
# Name: Star Rating, dtype: float64

# %%
apps.apply(lambda x:x**2)
# Out:
# Name
# Meesho: Online Shopping App          19.36
# Shopee: Online Shopping              16.81
# Instagram                            20.25
# MX Player: Videos, OTT & Games       17.64
# speedfiy                             19.36
#                                      ...
# Cutie SMS                            24.01
# MV Master - MV Master video maker    12.96
# Amazon Pay For Business              18.49
# Music Player - MP3 Player            21.16
# Safe CleanUp - Boost phone           16.00
# Name: Star Rating, Length: 600, dtype: float64

# %%
pd.read_csv('C:\download\course softwares\DATASETS\Google playstore apps\Google Playstore Apps.csv')
# Out:
#      Rank                               Name  \
# 0       1        Meesho: Online Shopping App
# 1       2            Shopee: Online Shopping
# 2       3                          Instagram
# 3       4     MX Player: Videos, OTT & Games
# 4       5                           speedfiy
# ..    ...                                ...
# 595   596                          Cutie SMS
# 596   597  MV Master - MV Master video maker
# 597   598            Amazon Pay For Business
# 598   599          Music Player - MP3 Player
# 599   600         Safe CleanUp - Boost phone
#
#                               Developer                 Category    Size  \
# 0                                Meesho                 Shopping   15 MB
# 1                                Shopee                 Shopping   68 MB
# 2                             Instagram                   Social   41 MB
# 3    MX Media (formerly J2 Interactive)  Video Players & Editors   36 MB
# ...

# %%
apps.hist();

# %%
google_apps =pd.read_csv('C:\download\course softwares\DATASETS\Google playstore apps\Google Playstore Apps.csv')

# %%
google_apps
# Out:
#      Rank                               Name  \
# 0       1        Meesho: Online Shopping App
# 1       2            Shopee: Online Shopping
# 2       3                          Instagram
# 3       4     MX Player: Videos, OTT & Games
# 4       5                           speedfiy
# ..    ...                                ...
# 595   596                          Cutie SMS
# 596   597  MV Master - MV Master video maker
# 597   598            Amazon Pay For Business
# 598   599          Music Player - MP3 Player
# 599   600         Safe CleanUp - Boost phone
#
#                               Developer                 Category    Size  \
# 0                                Meesho                 Shopping   15 MB
# 1                                Shopee                 Shopping   68 MB
# 2                             Instagram                   Social   41 MB
# 3    MX Media (formerly J2 Interactive)  Video Players & Editors   36 MB
# ...

# %%
google_apps.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Columns: 9 entries, Rank to Rated for
# dtypes: float64(1), int64(1), object(7)
# memory usage: 42.3+ KB

# %%
google_apps = google_apps.drop('Rank',axis=1)

# %%
google_apps
# Out:
#                                   Name                           Developer  \
# 0          Meesho: Online Shopping App                              Meesho
# 1              Shopee: Online Shopping                              Shopee
# 2                            Instagram                           Instagram
# 3       MX Player: Videos, OTT & Games  MX Media (formerly J2 Interactive)
# 4                             speedfiy             PRIME DIGITAL PTE. LTD.
# ..                                 ...                                 ...
# 595                          Cutie SMS                            Info Jod
# 596  MV Master - MV Master video maker   MV Master - MV Master video maker
# 597            Amazon Pay For Business                   Amazon Mobile LLC
# 598          Music Player - MP3 Player                             Apps10X
# 599         Safe CleanUp - Boost phone                           Surf tool
#
# ...

# %%
google_apps.sample(3)
# Out:
#                               Name                       Developer  \
# 86   X Sender Share: File Transfer  Everyday Apps by Appytome Tech
# 303  Aaj Tak Live - Hindi News App        TV Today Network Limited
# 287    Uplive-Live Stream, Go Live     Asia Innovations HK Limited
#
#              Category    Size  Star Rating Reviews Downloads Rated for
# 86              Tools   23 MB          4.1      7T      10L+        3+
# 303  News & Magazines   14 MB          4.0      2L      5Cr+        3+
# 287            Social  134 MB          3.9      1L      5Cr+       18+

# %%
google_apps.axes[1]
# Out:
# Index(['Name', 'Developer', 'Category', 'Size', 'Star Rating', 'Reviews',
#        'Downloads', 'Rated for'],
#       dtype='object')

# %%
google_apps.axes[1][5]
# Out:
# 'Reviews'

# %%
google_apps = google_apps.set_index('Name')

# %%
google_apps
# Out:
#                                                             Developer  \
# Name
# Meesho: Online Shopping App                                    Meesho
# Shopee: Online Shopping                                        Shopee
# Instagram                                                   Instagram
# MX Player: Videos, OTT & Games     MX Media (formerly J2 Interactive)
# speedfiy                                      PRIME DIGITAL PTE. LTD.
# ...                                                               ...
# Cutie SMS                                                    Info Jod
# MV Master - MV Master video maker   MV Master - MV Master video maker
# Amazon Pay For Business                             Amazon Mobile LLC
# Music Player - MP3 Player                                     Apps10X
# Safe CleanUp - Boost phone                                  Surf tool
#
#                                                   Category    Size  \
# Name
# ...

# %%
google_apps.set_index('Category')
# Out:
#                                                   Developer    Size  \
# Category
# Shopping                                             Meesho   15 MB
# Shopping                                             Shopee   68 MB
# Social                                            Instagram   41 MB
# Video Players & Editors  MX Media (formerly J2 Interactive)   36 MB
# Tools                               PRIME DIGITAL PTE. LTD.   12 MB
# ...                                                     ...     ...
# Entertainment                                      Info Jod  9.9 MB
# Video Players & Editors   MV Master - MV Master video maker   43 MB
# Business                                  Amazon Mobile LLC   24 MB
# Music & Audio                                       Apps10X  9.4 MB
# Tools                                             Surf tool   18 MB
#
#                          Star Rating Reviews Downloads Rated for
# Category
# ...

# %%
google_apps.set_index('Category',append=True)
# Out:
#                                                                                     Developer  \
# Name                              Category
# Meesho: Online Shopping App       Shopping                                             Meesho
# Shopee: Online Shopping           Shopping                                             Shopee
# Instagram                         Social                                            Instagram
# MX Player: Videos, OTT & Games    Video Players & Editors  MX Media (formerly J2 Interactive)
# speedfiy                          Tools                               PRIME DIGITAL PTE. LTD.
# ...                                                                                       ...
# Cutie SMS                         Entertainment                                      Info Jod
# MV Master - MV Master video maker Video Players & Editors   MV Master - MV Master video maker
# ...

# %%
google_apps.Developer.value_counts()
# Out:
# Google LLC               27
# InShot Inc.               9
# Amazon Mobile LLC         6
# Microsoft Corporation     5
# Meta Platforms, Inc.      4
#                          ..
# Gradeup                   1
# Translasion team          1
# PicsArt, Inc.             1
# Zili                      1
# Appliqato                 1
# Name: Developer, Length: 492, dtype: int64

# %%
google_apps
# Out:
#                                                             Developer  \
# Name
# Meesho: Online Shopping App                                    Meesho
# Shopee: Online Shopping                                        Shopee
# Instagram                                                   Instagram
# MX Player: Videos, OTT & Games     MX Media (formerly J2 Interactive)
# speedfiy                                      PRIME DIGITAL PTE. LTD.
# ...                                                               ...
# Cutie SMS                                                    Info Jod
# MV Master - MV Master video maker   MV Master - MV Master video maker
# Amazon Pay For Business                             Amazon Mobile LLC
# Music Player - MP3 Player                                     Apps10X
# Safe CleanUp - Boost phone                                  Surf tool
#
#                                                   Category    Size  \
# Name
# ...

# %%
google_apps.loc['Shopee: Online Shopping':'speedfiy','Category':'Downloads']
# Out:
#                                                Category   Size  Star Rating  \
# Name
# Shopee: Online Shopping                        Shopping  68 MB          4.1
# Instagram                                        Social  41 MB          4.3
# MX Player: Videos, OTT & Games  Video Players & Editors  36 MB          4.1
# speedfiy                                          Tools  12 MB          4.5
#
#                                Reviews Downloads
# Name
# Shopee: Online Shopping            76T      1Cr+
# Instagram                         13Cr    100Cr+
# MX Player: Videos, OTT & Games     1Cr    100Cr+
# speedfiy                           41T      1Cr+

# %%
google_apps.loc[['Instagram','speedfiy'],['Category','Downloads']]
# Out:
#           Category Downloads
# Name
# Instagram   Social    100Cr+
# speedfiy     Tools      1Cr+

# %%
google_apps.iloc[3]
# Out:
# Developer      MX Media (formerly J2 Interactive)
# Category                  Video Players & Editors
# Size                                        36 MB
# Star Rating                                   4.1
# Reviews                                       1Cr
# Downloads                                  100Cr+
# Rated for                                      3+
# Name: MX Player: Videos, OTT & Games, dtype: object

# %%
google_apps.iloc[[5,8,9]]
# Out:
#                                   Developer       Category   Size  \
# Name
# Snapchat                           Snap Inc  Communication  64 MB
# Telegram                    Telegram FZ-LLC  Communication  28 MB
# Chingari - powered by GARI         Chingari         Social  56 MB
#
#                             Star Rating Reviews Downloads Rated for
# Name
# Snapchat                            4.2     2Cr    100Cr+       12+
# Telegram                            4.3     1Cr    100Cr+       12+
# Chingari - powered by GARI          3.8      4L      5Cr+       12+

# %%
google_apps.iloc[[5,8,9],2:6]
# Out:
#                              Size  Star Rating Reviews Downloads
# Name
# Snapchat                    64 MB          4.2     2Cr    100Cr+
# Telegram                    28 MB          4.3     1Cr    100Cr+
# Chingari - powered by GARI  56 MB          3.8      4L      5Cr+

# %%
google_apps.iloc[8,5]
# Out:
# '100Cr+'

# %%
google_apps.head()
# Out:
#                                                          Developer  \
# Name
# Meesho: Online Shopping App                                 Meesho
# Shopee: Online Shopping                                     Shopee
# Instagram                                                Instagram
# MX Player: Videos, OTT & Games  MX Media (formerly J2 Interactive)
# speedfiy                                   PRIME DIGITAL PTE. LTD.
#
#                                                Category   Size  Star Rating  \
# Name
# Meesho: Online Shopping App                    Shopping  15 MB          4.4
# Shopee: Online Shopping                        Shopping  68 MB          4.1
# Instagram                                        Social  41 MB          4.3
# MX Player: Videos, OTT & Games  Video Players & Editors  36 MB          4.1
# speedfiy                                          Tools  12 MB          4.5
#
#                                Reviews Downloads Rated for
# Name
# ...

# %%
google_apps.at['Instagram','Reviews']
# Out:
# '13Cr'

# %%
google_apps.iat[2,4]
# Out:
# '13Cr'

# %%
google_apps_mini = google_apps.sample(10)

# %%
google_apps_mini
# Out:
#                                                                                        Developer  \
# Name
# All Recovery : Photo Video & Contacts                                       Photo and Video apps
# discovery+                                                         Discovery Communication India
# Amazon Music: Songs & Podcasts                                                 Amazon Mobile LLC
# Skincare App & Treatment For Hair Loss: CureSkin                             CureSkin Labs India
# JioCinema: Movies TV Originals                    Reliance Projects & Property Mgmt Services Ltd
# Pi Music Player - MP3 Player & YouTube Music                             Musicophilia Music Apps
# Upstox Old - Stocks, MF & IPOs                                                            Upstox
# bob World                                                                         Bank of Baroda
# PublicVibe - Local Videos from your Locality                                     Eterno Infotech
# ...

# %%
google_apps_mini.loc[:,['Category','Star Rating']]
# Out:
#                                                           Category  \
# Name
# All Recovery : Photo Video & Contacts                        Tools
# discovery+                                           Entertainment
# Amazon Music: Songs & Podcasts                       Music & Audio
# Skincare App & Treatment For Hair Loss: CureSkin  Health & Fitness
# JioCinema: Movies TV Originals                       Entertainment
# Pi Music Player - MP3 Player & YouTube Music         Music & Audio
# Upstox Old - Stocks, MF & IPOs                             Finance
# bob World                                                  Finance
# PublicVibe - Local Videos from your Locality                Social
# Photo Editor pro - SquarePic Stickers                  Photography
#
#                                                   Star Rating
# Name
# All Recovery : Photo Video & Contacts                     3.9
# discovery+                                                4.3
# ...

# %%
size = google_apps_mini.columns.get_loc('Size')

# %%
google_apps_mini.iloc[0:3,size:]
# Out:
#                                          Size  Star Rating Reviews Downloads  \
# Name
# All Recovery : Photo Video & Contacts  6.4 MB          3.9     57T      50L+
# discovery+                              13 MB          4.3     99T      1Cr+
# Amazon Music: Songs & Podcasts          97 MB          4.2     24L     10Cr+
#
#                                       Rated for
# Name
# All Recovery : Photo Video & Contacts        3+
# discovery+                                  16+
# Amazon Music: Songs & Podcasts              12+

# %%
google_apps_mini.head()
# Out:
#                                                                                        Developer  \
# Name
# All Recovery : Photo Video & Contacts                                       Photo and Video apps
# discovery+                                                         Discovery Communication India
# Amazon Music: Songs & Podcasts                                                 Amazon Mobile LLC
# Skincare App & Treatment For Hair Loss: CureSkin                             CureSkin Labs India
# JioCinema: Movies TV Originals                    Reliance Projects & Property Mgmt Services Ltd
#
#                                                           Category    Size  \
# Name
# All Recovery : Photo Video & Contacts                        Tools  6.4 MB
# discovery+                                           Entertainment   13 MB
# Amazon Music: Songs & Podcasts                       Music & Audio   97 MB
# ...

# %%
google_apps_mini.iloc[3,5]
# Out:
# '50L+'

# %%
google_apps.head()
# Out:
#                                                          Developer  \
# Name
# Meesho: Online Shopping App                                 Meesho
# Shopee: Online Shopping                                     Shopee
# Instagram                                                Instagram
# MX Player: Videos, OTT & Games  MX Media (formerly J2 Interactive)
# speedfiy                                   PRIME DIGITAL PTE. LTD.
#
#                                                Category   Size  Star Rating  \
# Name
# Meesho: Online Shopping App                    Shopping  15 MB          4.4
# Shopee: Online Shopping                        Shopping  68 MB          4.1
# Instagram                                        Social  41 MB          4.3
# MX Player: Videos, OTT & Games  Video Players & Editors  36 MB          4.1
# speedfiy                                          Tools  12 MB          4.5
#
#                                Reviews Downloads Rated for
# Name
# ...

# %%
google_apps = google_apps.replace('[a-zA-Z+&()-'']','',regex=True)

# %%
google_apps
# Out:
#                                   Developer Category  Size  Star Rating  \
# Name
# Meesho: Online Shopping App                            15           4.4
# Shopee: Online Shopping                                68           4.1
# Instagram                                              41           4.3
# MX Player: Videos, OTT & Games           2             36           4.1
# speedfiy                                . .            12           4.5
# ...                                     ...      ...   ...          ...
# Cutie SMS                                             9.9           4.9
# MV Master - MV Master video maker                      43           3.6
# Amazon Pay For Business                                24           4.3
# Music Player - MP3 Player                10           9.4           4.6
# Safe CleanUp - Boost phone                             18           4.0
#
#                                   Reviews Downloads Rated for
# Name
# ...

# %%
google_apps
# Out:
#                                   Developer Category  Size  Star Rating  \
# Name
# Meesho: Online Shopping App                            15           4.4
# Shopee: Online Shopping                                68           4.1
# Instagram                                              41           4.3
# MX Player: Videos, OTT & Games           2             36           4.1
# speedfiy                                . .            12           4.5
# ...                                     ...      ...   ...          ...
# Cutie SMS                                             9.9           4.9
# MV Master - MV Master video maker                      43           3.6
# Amazon Pay For Business                                24           4.3
# Music Player - MP3 Player                10           9.4           4.6
# Safe CleanUp - Boost phone                             18           4.0
#
#                                   Reviews Downloads Rated for
# Name
# ...

# %%
google_apps.filter(regex='[Mm]eesho',axis=0)
# Out:
#                             Developer Category Size  Star Rating Reviews  \
# Name
# Meesho: Online Shopping App                     15           4.4      15
#
#                             Downloads Rated for
# Name
# Meesho: Online Shopping App        10         3

# %%
google_apps.filter(regex='[Mm]eesho',axis=0)\
                   .loc[:,['Size','Star Rating','Downloads']]
# Out:
#                             Size  Star Rating Downloads
# Name
# Meesho: Online Shopping App  15           4.4        10

# %%
google_apps.sort_values(['Size','Star Rating'],ascending=[False,True])
# Out:
#                                      Developer Category  Size  Star Rating  \
# Name
# Adobe Lightroom: Photo Editor                             99           4.4
# Microsoft Office: Edit & Share                            99           4.5
# Amazon Music: Songs & Podcasts                            97           4.2
# ZeepLive - Live Video Chat                                92           3.9
# VITA - Video Editor & Maker                , .            92           4.3
# ...                                        ...      ...   ...          ...
# InShare - Share Apps & File Transfer         .            10           4.6
# HD Camera                                                1.8           4.0
# Google Find My Device                                    1.8           4.3
# Facebook Lite                              , .           1.6           3.9
# YouTube Kids                                                           4.0
#
# ...

# %%
google_apps = google_apps.rename(columns={'Star Rating':'Star_Rating','Rated for':'Rated_for'})

# %%
google_apps
# Out:
#                                   Developer Category  Size  Star_Rating  \
# Name
# Meesho: Online Shopping App                            15           4.4
# Shopee: Online Shopping                                68           4.1
# Instagram                                              41           4.3
# MX Player: Videos, OTT & Games           2             36           4.1
# speedfiy                                . .            12           4.5
# ...                                     ...      ...   ...          ...
# Cutie SMS                                             9.9           4.9
# MV Master - MV Master video maker                      43           3.6
# Amazon Pay For Business                                24           4.3
# Music Player - MP3 Player                10           9.4           4.6
# Safe CleanUp - Boost phone                             18           4.0
#
#                                   Reviews Downloads Rated_for
# Name
# ...

# %%
google_apps[google_apps.Star_Rating.between(3,4)]
# Out:
#                                                   Developer Category  Size  \
# Name
# ZOOM Cloud Meetings                                       .            47
# Chingari - powered by GARI                                             56
# Facebook                                                , .            51
# FacePlay - Face Swap Video                                             37
# ZEE5:Movies, Web Series & more                         5               21
# ...                                                     ...      ...   ...
# FFF FF Skin Tool, Elite Pass Bundles, Emote, Skin                      10
# Cast to TV & Screen Mirroring                                          11
# HD Camera                                                             1.8
# MV Master - MV Master video maker                                      43
# Safe CleanUp - Boost phone                                             18
#
# ...

# %%
google_apps.min(axis=1)
# Out:
# Name
# Meesho: Online Shopping App          4.4
# Shopee: Online Shopping              4.1
# Instagram                            4.3
# MX Player: Videos, OTT & Games       4.1
# speedfiy                             4.5
#                                     ...
# Cutie SMS                            4.9
# MV Master - MV Master video maker    3.6
# Amazon Pay For Business              4.3
# Music Player - MP3 Player            4.6
# Safe CleanUp - Boost phone           4.0
# Length: 600, dtype: float64

# %%
google_apps.max(axis=1)
# Out:
# Name
# Meesho: Online Shopping App          4.4
# Shopee: Online Shopping              4.1
# Instagram                            4.3
# MX Player: Videos, OTT & Games       4.1
# speedfiy                             4.5
#                                     ...
# Cutie SMS                            4.9
# MV Master - MV Master video maker    3.6
# Amazon Pay For Business              4.3
# Music Player - MP3 Player            4.6
# Safe CleanUp - Boost phone           4.0
# Length: 600, dtype: float64

# %%
google_apps.nlargest(10,'Star_Rating')
# Out:
#                                                Developer Category  Size  \
# Name
# Cutie SMS                                                          9.9
# Image to PDF Converter - JPG to PDF, PDF Maker         .           9.6
# Collage Maker | Photo Editor                                        12
# Sri Mandir - Your Own Temple                                        31
# Home Workout - No Equipment                                         15
# Six Pack in 30 Days                                                 14
# TocToc - live video chat                                            40
# Video downloader for Instagram                                     8.5
# India's largest Community app - Kutumb                              15
# OKEN - CamScanner, PDF scanner                       . .            31
#
#                                                 Star_Rating Reviews Downloads  \
# Name
# Cutie SMS                                               4.9       6         1
# ...

# %%
google_apps.Reviews = google_apps.Reviews.astype(float)

# %%
google_apps.Rated_for = google_apps.Rated_for.astype(float)

# %%
google_apps.nsmallest(10,['Star_Rating','Reviews','Rated_for'])
# Out:
#                                        Developer Category  Size  Star_Rating  \
# Name
# HD Video Screen Mirroring                                  7.5           2.1
# HD Video Screen Mirroring Cast                             8.2           2.1
# Mylab CoviSelf                                              26           2.6
# Co-WIN Vaccinator App                                       11           2.8
# Live Cricket TV - HD Live Cricket 2021                      10           2.8
# Mivita - Face Swap Video Maker                              64           3.0
# HD Video Projector Simulator                                12           3.0
# Tinder - Match. Chat. Date. Your Way.                       53           3.0
# Shield VPN - Private VPN Proxy                              14           3.1
# Big Bazaar - Making India Beautiful                         11           3.1
#
#                                         Reviews Downloads  Rated_for
# Name
# ...

# %%
google_apps.loc[:,'Star_Rating'].nlargest(10)
# Out:
# Name
# Cutie SMS                                         4.9
# Image to PDF Converter - JPG to PDF, PDF Maker    4.8
# Collage Maker | Photo Editor                      4.8
# Sri Mandir - Your Own Temple                      4.8
# Home Workout - No Equipment                       4.8
# Six Pack in 30 Days                               4.8
# TocToc - live video chat                          4.8
# Video downloader for Instagram                    4.7
# India's largest Community app - Kutumb            4.7
# OKEN - CamScanner, PDF scanner                    4.7
# Name: Star_Rating, dtype: float64

# %%
google_apps.Star_Rating.nlargest(10)
# Out:
# Name
# Cutie SMS                                         4.9
# Image to PDF Converter - JPG to PDF, PDF Maker    4.8
# Collage Maker | Photo Editor                      4.8
# Sri Mandir - Your Own Temple                      4.8
# Home Workout - No Equipment                       4.8
# Six Pack in 30 Days                               4.8
# TocToc - live video chat                          4.8
# Video downloader for Instagram                    4.7
# India's largest Community app - Kutumb            4.7
# OKEN - CamScanner, PDF scanner                    4.7
# Name: Star_Rating, dtype: float64

# %%
google_apps.filter(regex='[Ii]nstagram',axis=0).Star_Rating.nlargest(1)
# Out:
# Name
# Video downloader for Instagram    4.7
# Name: Star_Rating, dtype: float64

# %%
google_apps.sample(4).sample(2,axis=1)
# Out:
#                                 Rated_for Downloads
# Name
# Yono Lite SBI - Mobile Banking        3.0         5
# ShareKaro: File Sharing               3.0         5
# VPN Master Pro - Fast & Secure        3.0         5
# CoinDCX:Bitcoin Investment App        3.0         1

# %%
google_apps[google_apps.Star_Rating.between(3,4)].Rated_for.nsmallest(1)
# Out:
# Name
# ZOOM Cloud Meetings    3.0
# Name: Rated_for, dtype: float64

# %%
google_apps =pd.read_csv('C:\download\course softwares\DATASETS\Google playstore apps\Google Playstore Apps.csv')

# %%
google_apps.rename(columns={'Star Rating':'Star_Rating','Rated for':'Rated_for'},inplace=True)

# %%
google_apps
# Out:
#      Rank                               Name  \
# 0       1        Meesho: Online Shopping App
# 1       2            Shopee: Online Shopping
# 2       3                          Instagram
# 3       4     MX Player: Videos, OTT & Games
# 4       5                           speedfiy
# ..    ...                                ...
# 595   596                          Cutie SMS
# 596   597  MV Master - MV Master video maker
# 597   598            Amazon Pay For Business
# 598   599          Music Player - MP3 Player
# 599   600         Safe CleanUp - Boost phone
#
#                               Developer                 Category    Size  \
# 0                                Meesho                 Shopping   15 MB
# 1                                Shopee                 Shopping   68 MB
# 2                             Instagram                   Social   41 MB
# 3    MX Media (formerly J2 Interactive)  Video Players & Editors   36 MB
# ...

# %%
google_apps[google_apps.Rank>40]
# Out:
#      Rank                                        Name  \
# 40     41              Noizz: video editor with music
# 41     42              Mivi:Music&Lyrical Video Maker
# 42     43                   Amazon India - Shop & Pay
# 43     44              Mivita - Face Swap Video Maker
# 44     45  Moj - India's Most Popular Short Video App
# ..    ...                                         ...
# 595   596                                   Cutie SMS
# 596   597           MV Master - MV Master video maker
# 597   598                     Amazon Pay For Business
# 598   599                   Music Player - MP3 Player
# 599   600                  Safe CleanUp - Boost phone
#
#                              Developer                 Category    Size  \
# 40                          Noizz Team                    Tools   37 MB
# 41                  Music Video Studio  Video Players & Editors   43 MB
# 42                   Amazon Mobile LLC                 Shopping   57 MB
# ...

# %%
google_apps.Category.unique()
# Out:
# array(['Shopping', 'Social', 'Video Players & Editors', 'Tools',
#        'Communication', 'Business', 'Finance', 'Productivity',
#        'Music & Audio', 'Entertainment', 'News & Magazines',
#        'Photography', 'Travel & Local', 'Food & Drink', 'Auto & Vehicles',
#        'Education', 'Books & Reference', 'Art & Design', 'Sports',
#        'Personalisation', 'Lifestyle', 'Health & Fitness',
#        'Maps & Navigation', 'Dating', 'Medical', 'Comics', 'Weather',
#        'House & Home'], dtype=object)

# %%
google_apps[google_apps.Category.isin(['Social','Sports','Weather'])]
# Out:
#      Rank                                               Name  \
# 2       3                                          Instagram
# 9      10                         Chingari - powered by GARI
# 16     17                                           Facebook
# 30     31                             Josh: Short Videos App
# 36     37                          ShareChat - Made in India
# 38     39                         Rizzle - Short Video Maker
# 44     45         Moj - India's Most Popular Short Video App
# 46     47                                      Facebook Lite
# 47     48                       Tiki - Short Video Community
# 48     49                         MX TakaTak Short Video App
# 50     51                                     Instagram Lite
# 54     55                       Public - Indian Local Videos
# 84     85                           AIO Social Media Browser
# 100   101                     Video downloader for Instagram
# ...

# %%
google_apps[google_apps.Rank.between(30,50)]
# Out:
#     Rank                                               Name  \
# 29    30                     PLAYit-All in One Video Player
# 30    31                             Josh: Short Videos App
# 31    32                     ZEE5:Movies, Web Series & more
# 32    33                        JioMart Online Shopping App
# 33    34  Dailyhunt - Local & National News, Videos, Cri...
# 34    35     Airtel Thanks – Recharge, Bill Pay, UPI & Bank
# 35    36                     Translate All- Easy Translator
# 36    37                          ShareChat - Made in India
# 37    38  JioSaavn Music & Radio – JioTunes, Podcasts, S...
# 38    39                         Rizzle - Short Video Maker
# 39    40                     Wynk Music -Songs & HelloTunes
# 40    41                     Noizz: video editor with music
# 41    42                     Mivi:Music&Lyrical Video Maker
# 42    43                          Amazon India - Shop & Pay
# 43    44                     Mivita - Face Swap Video Maker
# ...

# %%
google_apps[google_apps.Rank<=25]
# Out:
#     Rank                                               Name  \
# 0      1                        Meesho: Online Shopping App
# 1      2                            Shopee: Online Shopping
# 2      3                                          Instagram
# 3      4                     MX Player: Videos, OTT & Games
# 4      5                                           speedfiy
# 5      6                                           Snapchat
# 6      7                                ZOOM Cloud Meetings
# 7      8                       Flipkart Online Shopping App
# 8      9                                           Telegram
# 9     10                         Chingari - powered by GARI
# 10    11                     mAst: Music Status Video Maker
# 11    12                                        Google Meet
# 12    13      PhonePe: UPI, Recharge, Investment, Insurance
# 13    14                      Truecaller: Caller ID & Block
# 14    15                          MyJio: For Everything Jio
# ...

# %%
google_apps[(google_apps.Category=='Social') & (google_apps.Rank<=25)]
# Out:
#     Rank                        Name             Developer Category   Size  \
# 2      3                   Instagram             Instagram   Social  41 MB
# 9     10  Chingari - powered by GARI              Chingari   Social  56 MB
# 16    17                    Facebook  Meta Platforms, Inc.   Social  51 MB
#
#     Star_Rating Reviews Downloads Rated_for
# 2           4.3    13Cr    100Cr+       12+
# 9           3.8      4L      5Cr+       12+
# 16          4.0    12Cr    500Cr+       12+

# %%
google_apps[(google_apps.Category=='Social')&(google_apps.Rank<=25)&(google_apps.Star_Rating>=4)&~(google_apps.Developer.isin(['All Video Downloader','Hotstar']))]
# Out:
#     Rank       Name             Developer Category   Size  Star_Rating  \
# 2      3  Instagram             Instagram   Social  41 MB          4.3
# 16    17   Facebook  Meta Platforms, Inc.   Social  51 MB          4.0
#
#    Reviews Downloads Rated_for
# 2     13Cr    100Cr+       12+
# 16    12Cr    500Cr+       12+

# %%
google_apps.head()
# Out:
#    Rank                            Name                           Developer  \
# 0     1     Meesho: Online Shopping App                              Meesho
# 1     2         Shopee: Online Shopping                              Shopee
# 2     3                       Instagram                           Instagram
# 3     4  MX Player: Videos, OTT & Games  MX Media (formerly J2 Interactive)
# 4     5                        speedfiy             PRIME DIGITAL PTE. LTD.
#
#                   Category   Size  Star_Rating Reviews Downloads Rated_for
# 0                 Shopping  15 MB          4.4     15L     10Cr+        3+
# 1                 Shopping  68 MB          4.1     76T      1Cr+        3+
# 2                   Social  41 MB          4.3    13Cr    100Cr+       12+
# 3  Video Players & Editors  36 MB          4.1     1Cr    100Cr+        3+
# 4                    Tools  12 MB          4.5     41T      1Cr+        3+

# %%
Business_and_1Cr = (google_apps.Category=='Business') & (google_apps.Downloads=='1Cr+')

# %%
Business_and_1Cr
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 595    False
# 596    False
# 597    False
# 598    False
# 599    False
# Length: 600, dtype: bool

# %%
Social_and_10Cr = (google_apps.Category=='Social') & (google_apps.Downloads=='10Cr+')

# %%
Social_and_10Cr
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 595    False
# 596    False
# 597    False
# 598    False
# 599    False
# Length: 600, dtype: bool

# %%
google_apps.loc[Business_and_1Cr | Social_and_10Cr]
# Out:
#      Rank                                               Name  \
# 30     31                             Josh: Short Videos App
# 36     37                          ShareChat - Made in India
# 44     45         Moj - India's Most Popular Short Video App
# 48     49                         MX TakaTak Short Video App
# 50     51                                     Instagram Lite
# 54     55                       Public - Indian Local Videos
# 95     96  apna: Job Search India, Vacancy Alert, Online ...
# 125   126                                   PhonePe Business
# 218   219    Shop101: Resell, Work From Home, Make Money App
# 228   229  Scanner Go: Cam Scanner, PDF Scanner, Scanner App
# 282   283                    AnyDesk Remote Desktop Software
# 379   380                          Naukri.com Job Search App
# 552   553                           WorkIndia Job Search App
#
#                                            Developer  Category    Size  \
# ...

# %%
google_apps.head()
# Out:
#    Rank                            Name                           Developer  \
# 0     1     Meesho: Online Shopping App                              Meesho
# 1     2         Shopee: Online Shopping                              Shopee
# 2     3                       Instagram                           Instagram
# 3     4  MX Player: Videos, OTT & Games  MX Media (formerly J2 Interactive)
# 4     5                        speedfiy             PRIME DIGITAL PTE. LTD.
#
#                   Category   Size  Star_Rating Reviews Downloads Rated_for
# 0                 Shopping  15 MB          4.4     15L     10Cr+        3+
# 1                 Shopping  68 MB          4.1     76T      1Cr+        3+
# 2                   Social  41 MB          4.3    13Cr    100Cr+       12+
# 3  Video Players & Editors  36 MB          4.1     1Cr    100Cr+        3+
# 4                    Tools  12 MB          4.5     41T      1Cr+        3+

# %%
Finance_50 = (google_apps.Category=='Finance') & (google_apps.Rank<=50)

# %%
google_apps[Finance_50]
# Out:
#     Rank                                               Name  \
# 12    13      PhonePe: UPI, Recharge, Investment, Insurance
# 21    22  Paytm -UPI, Money Transfer, Recharge, Bill Pay...
# 28    29                     Google Pay: Secure UPI payment
#
#                             Developer Category   Size  Star_Rating Reviews  \
# 12                            PhonePe  Finance  35 MB          4.3     77L
# 21  Paytm - One97 Communications Ltd.  Finance  31 MB          4.6     1Cr
# 28                         Google LLC  Finance  20 MB          4.2     71L
#
#    Downloads Rated_for
# 12     10Cr+        3+
# 21     10Cr+        3+
# 28     50Cr+        3+

# %%
google_apps.loc[Finance_50,['Reviews','Downloads']]
# Out:
#    Reviews Downloads
# 12     77L     10Cr+
# 21     1Cr     10Cr+
# 28     71L     50Cr+

# %%
r_cols = google_apps.columns.str.startswith('R')

# %%
google_apps.loc[Finance_50,r_cols]
# Out:
#     Rank Reviews Rated_for
# 12    13     77L        3+
# 21    22     1Cr        3+
# 28    29     71L        3+

# %%
google_apps.loc[Finance_50,'Size']
# Out:
# 12    35 MB
# 21    31 MB
# 28    20 MB
# Name: Size, dtype: object

# %%
google_apps.loc[[0,150],('Rank','Name')]
# Out:
#      Rank                         Name
# 0       1  Meesho: Online Shopping App
# 150   151                   BoloJi Pro

# %%
google_apps.sort_values('Star_Rating',ascending=False)
# Out:
#      Rank                                               Name  \
# 595   596                                          Cutie SMS
# 183   184     Image to PDF Converter - JPG to PDF, PDF Maker
# 439   440                        Home Workout - No Equipment
# 480   481                                Six Pack in 30 Days
# 528   529                           TocToc - live video chat
# ..    ...                                                ...
# 346   347             Live Cricket TV - HD Live Cricket 2021
# 352   353                                     Mylab CoviSelf
# 171   172                          HD Video Screen Mirroring
# 400   401                     HD Video Screen Mirroring Cast
# 236   237  EasyShare – Ultrafast File Transfer, Free & No...
#
#                                  Developer          Category    Size  \
# 595                               Info Jod     Entertainment  9.9 MB
# 183                     Simple Design Ltd.      Productivity  9.6 MB
# ...

# %%
google_apps.sort_index(axis=1)
# Out:
#                     Category                           Developer Downloads  \
# 0                   Shopping                              Meesho     10Cr+
# 1                   Shopping                              Shopee      1Cr+
# 2                     Social                           Instagram    100Cr+
# 3    Video Players & Editors  MX Media (formerly J2 Interactive)    100Cr+
# 4                      Tools             PRIME DIGITAL PTE. LTD.      1Cr+
# ..                       ...                                 ...       ...
# 595            Entertainment                            Info Jod       1L+
# 596  Video Players & Editors   MV Master - MV Master video maker      1Cr+
# 597                 Business                   Amazon Mobile LLC      10L+
# 598            Music & Audio                             Apps10X      5Cr+
# 599                    Tools                           Surf tool      10L+
#
# ...

# %%
google_apps.reset_index()
# Out:
#      index  Rank                               Name  \
# 0        0     1        Meesho: Online Shopping App
# 1        1     2            Shopee: Online Shopping
# 2        2     3                          Instagram
# 3        3     4     MX Player: Videos, OTT & Games
# 4        4     5                           speedfiy
# ..     ...   ...                                ...
# 595    595   596                          Cutie SMS
# 596    596   597  MV Master - MV Master video maker
# 597    597   598            Amazon Pay For Business
# 598    598   599          Music Player - MP3 Player
# 599    599   600         Safe CleanUp - Boost phone
#
#                               Developer                 Category    Size  \
# 0                                Meesho                 Shopping   15 MB
# 1                                Shopee                 Shopping   68 MB
# 2                             Instagram                   Social   41 MB
# ...

# %%
google_apps.head()
# Out:
#    Rank                            Name                           Developer  \
# 0     1     Meesho: Online Shopping App                              Meesho
# 1     2         Shopee: Online Shopping                              Shopee
# 2     3                       Instagram                           Instagram
# 3     4  MX Player: Videos, OTT & Games  MX Media (formerly J2 Interactive)
# 4     5                        speedfiy             PRIME DIGITAL PTE. LTD.
#
#                   Category   Size  Star_Rating Reviews Downloads Rated_for
# 0                 Shopping  15 MB          4.4     15L     10Cr+        3+
# 1                 Shopping  68 MB          4.1     76T      1Cr+        3+
# 2                   Social  41 MB          4.3    13Cr    100Cr+       12+
# 3  Video Players & Editors  36 MB          4.1     1Cr    100Cr+        3+
# 4                    Tools  12 MB          4.5     41T      1Cr+        3+

# %%
google_apps_lite = google_apps.iloc[:4,:4]

# %%
google_apps_lite
# Out:
#    Rank                            Name                           Developer  \
# 0     1     Meesho: Online Shopping App                              Meesho
# 1     2         Shopee: Online Shopping                              Shopee
# 2     3                       Instagram                           Instagram
# 3     4  MX Player: Videos, OTT & Games  MX Media (formerly J2 Interactive)
#
#                   Category
# 0                 Shopping
# 1                 Shopping
# 2                   Social
# 3  Video Players & Editors

# %%
google_apps_lite.reindex(index=[2,0,3,1],columns=['Name','Rank','Category','Developer'])
# Out:
#                              Name  Rank                 Category  \
# 2                       Instagram     3                   Social
# 0     Meesho: Online Shopping App     1                 Shopping
# 3  MX Player: Videos, OTT & Games     4  Video Players & Editors
# 1         Shopee: Online Shopping     2                 Shopping
#
#                             Developer
# 2                           Instagram
# 0                              Meesho
# 3  MX Media (formerly J2 Interactive)
# 1                              Shopee

# %%
google_apps.reindex(index=[2,3,1,0]).sort_index(axis=1)
# Out:
#                   Category                           Developer Downloads  \
# 2                   Social                           Instagram    100Cr+
# 3  Video Players & Editors  MX Media (formerly J2 Interactive)    100Cr+
# 1                 Shopping                              Shopee      1Cr+
# 0                 Shopping                              Meesho     10Cr+
#
#                              Name  Rank Rated_for Reviews   Size  Star_Rating
# 2                       Instagram     3       12+    13Cr  41 MB          4.3
# 3  MX Player: Videos, OTT & Games     4        3+     1Cr  36 MB          4.1
# 1         Shopee: Online Shopping     2        3+     76T  68 MB          4.1
# 0     Meesho: Online Shopping App     1        3+     15L  15 MB          4.4

# %%
google_apps.reindex(index=[2,3,1,0],columns=sorted(google_apps.columns)[:7])
# Out:
#                   Category                           Developer Downloads  \
# 2                   Social                           Instagram    100Cr+
# 3  Video Players & Editors  MX Media (formerly J2 Interactive)    100Cr+
# 1                 Shopping                              Shopee      1Cr+
# 0                 Shopping                              Meesho     10Cr+
#
#                              Name  Rank Rated_for Reviews
# 2                       Instagram     3       12+    13Cr
# 3  MX Player: Videos, OTT & Games     4        3+     1Cr
# 1         Shopee: Online Shopping     2        3+     76T
# 0     Meesho: Online Shopping App     1        3+     15L

# %%
google_apps.sort_values('Rank',ascending=False)
# Out:
#      Rank                               Name  \
# 599   600         Safe CleanUp - Boost phone
# 598   599          Music Player - MP3 Player
# 597   598            Amazon Pay For Business
# 596   597  MV Master - MV Master video maker
# 595   596                          Cutie SMS
# ..    ...                                ...
# 4       5                           speedfiy
# 3       4     MX Player: Videos, OTT & Games
# 2       3                          Instagram
# 1       2            Shopee: Online Shopping
# 0       1        Meesho: Online Shopping App
#
#                               Developer                 Category    Size  \
# 599                           Surf tool                    Tools   18 MB
# 598                             Apps10X            Music & Audio  9.4 MB
# 597                   Amazon Mobile LLC                 Business   24 MB
# 596   MV Master - MV Master video maker  Video Players & Editors   43 MB
# ...

# %%
google_apps.loc[google_apps.Rank.idxmin()]
# Out:
# Rank                                     1
# Name           Meesho: Online Shopping App
# Developer                           Meesho
# Category                          Shopping
# Size                                 15 MB
# Star_Rating                            4.4
# Reviews                                15L
# Downloads                            10Cr+
# Rated_for                               3+
# Name: 0, dtype: object

# %%
google_apps.set_index('Category').sort_index()
# Out:
#                    Rank                                       Name  \
# Category
# Art & Design        377                               ibis Paint X
# Art & Design        211                                 Sketchbook
# Art & Design        110               Canva: Design, Photo & Video
# Auto & Vehicles      82                    RTO Vehicle Information
# Books & Reference   265  motesFF Challenge - All motes with dances
# ...                 ...                                        ...
# Weather             350                              Daily Weather
# Weather             560    Ramp Car Stunts: Crazy Car Racing Games
# Weather             395             Sweet Bakery- Girls Cake Games
# Weather             462             Coach Bus Simulator: Bus Games
# Weather             466              Tractor Driving Farming Games
#
#                                                           Developer    Size  \
# Category
# ...

# %%
google_apps.sort_values(['Category','Star_Rating'] ,ascending=[True,False])
# Out:
#      Rank                                               Name  \
# 109   110                       Canva: Design, Photo & Video
# 376   377                                       ibis Paint X
# 210   211                                         Sketchbook
# 81     82                            RTO Vehicle Information
# 476   477                      Amazon Kindle - eBooks & more
# ..    ...                                                ...
# 443   444                      Big Tractor Farming Simulator
# 461   462                     Coach Bus Simulator: Bus Games
# 465   466                      Tractor Driving Farming Games
# 366   367  Spider Rope SuperHero Vice City Gangster Fighting
# 559   560            Ramp Car Stunts: Crazy Car Racing Games
#
#                                             Developer           Category  \
# 109                                             Canva       Art & Design
# 376                                         ibis inc.       Art & Design
# ...

# %%
google_apps.loc[google_apps.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Developer, Category, Size, Star_Rating, Reviews, Downloads, Rated_for]
# Index: []

# %%
google_apps.drop(20,axis=0)
# Out:
#      Rank                               Name  \
# 0       1        Meesho: Online Shopping App
# 1       2            Shopee: Online Shopping
# 2       3                          Instagram
# 3       4     MX Player: Videos, OTT & Games
# 4       5                           speedfiy
# ..    ...                                ...
# 595   596                          Cutie SMS
# 596   597  MV Master - MV Master video maker
# 597   598            Amazon Pay For Business
# 598   599          Music Player - MP3 Player
# 599   600         Safe CleanUp - Boost phone
#
#                               Developer                 Category    Size  \
# 0                                Meesho                 Shopping   15 MB
# 1                                Shopee                 Shopping   68 MB
# 2                             Instagram                   Social   41 MB
# 3    MX Media (formerly J2 Interactive)  Video Players & Editors   36 MB
# ...

# %%
google_apps.drop(index=[2,3,4,5])
# Out:
#      Rank                               Name  \
# 0       1        Meesho: Online Shopping App
# 1       2            Shopee: Online Shopping
# 6       7                ZOOM Cloud Meetings
# 7       8       Flipkart Online Shopping App
# 8       9                           Telegram
# ..    ...                                ...
# 595   596                          Cutie SMS
# 596   597  MV Master - MV Master video maker
# 597   598            Amazon Pay For Business
# 598   599          Music Player - MP3 Player
# 599   600         Safe CleanUp - Boost phone
#
#                              Developer                 Category    Size  \
# 0                               Meesho                 Shopping   15 MB
# 1                               Shopee                 Shopping   68 MB
# 6                              zoom.us                 Business   47 MB
# 7                             Flipkart                 Shopping   18 MB
# ...

# %%
google_apps.drop(columns=['Size','Reviews','Rated_for'])
# Out:
#      Rank                               Name  \
# 0       1        Meesho: Online Shopping App
# 1       2            Shopee: Online Shopping
# 2       3                          Instagram
# 3       4     MX Player: Videos, OTT & Games
# 4       5                           speedfiy
# ..    ...                                ...
# 595   596                          Cutie SMS
# 596   597  MV Master - MV Master video maker
# 597   598            Amazon Pay For Business
# 598   599          Music Player - MP3 Player
# 599   600         Safe CleanUp - Boost phone
#
#                               Developer                 Category  Star_Rating  \
# 0                                Meesho                 Shopping          4.4
# 1                                Shopee                 Shopping          4.1
# 2                             Instagram                   Social          4.3
# 3    MX Media (formerly J2 Interactive)  Video Players & Editors          4.1
# ...

# %%
google_apps.pop('Name')
# Out:
# 0            Meesho: Online Shopping App
# 1                Shopee: Online Shopping
# 2                              Instagram
# 3         MX Player: Videos, OTT & Games
# 4                               speedfiy
#                      ...
# 595                            Cutie SMS
# 596    MV Master - MV Master video maker
# 597              Amazon Pay For Business
# 598            Music Player - MP3 Player
# 599           Safe CleanUp - Boost phone
# Name: Name, Length: 600, dtype: object

# %%
google_apps =pd.read_csv('C:\download\course softwares\DATASETS\Google playstore apps\Google Playstore Apps.csv')

# %%
google_apps.rename(columns={'Star Rating':'Star_Rating','Rated for':'Rated_for'},inplace=True)

# %%
google_apps
# Out:
#      Rank                               Name  \
# 0       1        Meesho: Online Shopping App
# 1       2            Shopee: Online Shopping
# 2       3                          Instagram
# 3       4     MX Player: Videos, OTT & Games
# 4       5                           speedfiy
# ..    ...                                ...
# 595   596                          Cutie SMS
# 596   597  MV Master - MV Master video maker
# 597   598            Amazon Pay For Business
# 598   599          Music Player - MP3 Player
# 599   600         Safe CleanUp - Boost phone
#
#                               Developer                 Category    Size  \
# 0                                Meesho                 Shopping   15 MB
# 1                                Shopee                 Shopping   68 MB
# 2                             Instagram                   Social   41 MB
# 3    MX Media (formerly J2 Interactive)  Video Players & Editors   36 MB
# ...

# %%
google_apps.isna()
# Out:
#       Rank   Name  Developer  Category   Size  Star_Rating  Reviews  \
# 0    False  False      False     False  False        False    False
# 1    False  False      False     False  False        False    False
# 2    False  False      False     False  False        False    False
# 3    False  False      False     False  False        False    False
# 4    False  False      False     False  False        False    False
# ..     ...    ...        ...       ...    ...          ...      ...
# 595  False  False      False     False  False        False    False
# 596  False  False      False     False  False        False    False
# 597  False  False      False     False  False        False    False
# 598  False  False      False     False  False        False    False
# 599  False  False      False     False  False        False    False
#
#      Downloads  Rated_for
# 0        False      False
# 1        False      False
# 2        False      False
# 3        False      False
# ...

# %%
np.count_nonzero(google_apps.isna())
# Out:
# 2

# %%
google_apps.loc[google_apps.isna().values]
# Out:
#      Rank                                               Name  \
# 236   237  EasyShare – Ultrafast File Transfer, Free & No...
# 236   237  EasyShare – Ultrafast File Transfer, Free & No...
#
#                                  Developer Category   Size  Star_Rating  \
# 236  Vivo Communication Technology Co. Ltd    Tools  13 MB          NaN
# 236  Vivo Communication Technology Co. Ltd    Tools  13 MB          NaN
#
#     Reviews Downloads Rated_for
# 236     NaN     10Cr+        3+
# 236     NaN     10Cr+        3+

# %%
google_apps.loc[google_apps.isna().values].drop_duplicates()
# Out:
#      Rank                                               Name  \
# 236   237  EasyShare – Ultrafast File Transfer, Free & No...
#
#                                  Developer Category   Size  Star_Rating  \
# 236  Vivo Communication Technology Co. Ltd    Tools  13 MB          NaN
#
#     Reviews Downloads Rated_for
# 236     NaN     10Cr+        3+

# %%
google_apps.fillna({'Star_Rating':4.3,'Reviews':'2Cr'}).loc[[236]]
# Out:
#      Rank                                               Name  \
# 236   237  EasyShare – Ultrafast File Transfer, Free & No...
#
#                                  Developer Category   Size  Star_Rating  \
# 236  Vivo Communication Technology Co. Ltd    Tools  13 MB          4.3
#
#     Reviews Downloads Rated_for
# 236     2Cr     10Cr+        3+

# %%
google_apps.dropna(axis=1,how='any').loc[[236]]
# Out:
#      Rank                                               Name  \
# 236   237  EasyShare – Ultrafast File Transfer, Free & No...
#
#                                  Developer Category   Size Downloads Rated_for
# 236  Vivo Communication Technology Co. Ltd    Tools  13 MB     10Cr+        3+

# %%
google_apps.head()
# Out:
#    Rank                            Name                           Developer  \
# 0     1     Meesho: Online Shopping App                              Meesho
# 1     2         Shopee: Online Shopping                              Shopee
# 2     3                       Instagram                           Instagram
# 3     4  MX Player: Videos, OTT & Games  MX Media (formerly J2 Interactive)
# 4     5                        speedfiy             PRIME DIGITAL PTE. LTD.
#
#                   Category   Size  Star_Rating Reviews Downloads Rated_for
# 0                 Shopping  15 MB          4.4     15L     10Cr+        3+
# 1                 Shopping  68 MB          4.1     76T      1Cr+        3+
# 2                   Social  41 MB          4.3    13Cr    100Cr+       12+
# 3  Video Players & Editors  36 MB          4.1     1Cr    100Cr+        3+
# 4                    Tools  12 MB          4.5     41T      1Cr+        3+

# %%
apps2 = google_apps.drop(index=[2,5,9] , columns='Rated_for')

# %%
apps2
# Out:
#      Rank                               Name  \
# 0       1        Meesho: Online Shopping App
# 1       2            Shopee: Online Shopping
# 3       4     MX Player: Videos, OTT & Games
# 4       5                           speedfiy
# 6       7                ZOOM Cloud Meetings
# ..    ...                                ...
# 595   596                          Cutie SMS
# 596   597  MV Master - MV Master video maker
# 597   598            Amazon Pay For Business
# 598   599          Music Player - MP3 Player
# 599   600         Safe CleanUp - Boost phone
#
#                               Developer                 Category    Size  \
# 0                                Meesho                 Shopping   15 MB
# 1                                Shopee                 Shopping   68 MB
# 3    MX Media (formerly J2 Interactive)  Video Players & Editors   36 MB
# 4               PRIME DIGITAL PTE. LTD.                    Tools   12 MB
# ...

# %%
apps2.Category.nunique()
# Out:
# 28

# %%
apps2.drop_duplicates(['Size','Star_Rating','Reviews'],keep='first').loc[:,['Name','Rank']]
# Out:
#                                   Name  Rank
# 0          Meesho: Online Shopping App     1
# 1              Shopee: Online Shopping     2
# 3       MX Player: Videos, OTT & Games     4
# 4                             speedfiy     5
# 6                  ZOOM Cloud Meetings     7
# ..                                 ...   ...
# 595                          Cutie SMS   596
# 596  MV Master - MV Master video maker   597
# 597            Amazon Pay For Business   598
# 598          Music Player - MP3 Player   599
# 599         Safe CleanUp - Boost phone   600
#
# [593 rows x 2 columns]

# %%
google_apps.agg('mean')
# Out:
# Rank           300.500000
# Star_Rating      4.156427
# dtype: float64

# %%
google_apps.agg('min')
# Out:
# Rank                                                          1
# Name           1 Minute Me Aadhar Loan - आधार कार्ड पे लोन गाइड
# Developer                                        3B Game Studio
# Category                                           Art & Design
# Size                                                     1.6 MB
# Star_Rating                                                 2.1
# Downloads                                                100Cr+
# Rated_for                                                   12+
# dtype: object

# %%
google_apps.agg(['min','max','mean'])
# Out:
#        Rank                                              Name  \
# min     1.0  1 Minute Me Aadhar Loan - आधार कार्ड पे लोन गाइड
# max   600.0               गाय भैंस wala पशुमेला - Animall app
# mean  300.5                                               NaN
#
#                Developer      Category              Size  Star_Rating  \
# min       3B Game Studio  Art & Design            1.6 MB     2.100000
# max   पशु मेला - Animall       Weather  Teacher Approved     4.900000
# mean                 NaN           NaN               NaN     4.156427
#
#      Downloads Rated_for
# min     100Cr+       12+
# max        5L+        7+
# mean       NaN       NaN

# %%
google_apps.select_dtypes(np.number).agg(['min','max','mean'])
# Out:
#        Rank  Star_Rating
# min     1.0     2.100000
# max   600.0     4.900000
# mean  300.5     4.156427

# %%
google_apps.head()
# Out:
#    Rank                            Name                           Developer  \
# 0     1     Meesho: Online Shopping App                              Meesho
# 1     2         Shopee: Online Shopping                              Shopee
# 2     3                       Instagram                           Instagram
# 3     4  MX Player: Videos, OTT & Games  MX Media (formerly J2 Interactive)
# 4     5                        speedfiy             PRIME DIGITAL PTE. LTD.
#
#                   Category   Size  Star_Rating Reviews Downloads Rated_for
# 0                 Shopping  15 MB          4.4     15L     10Cr+        3+
# 1                 Shopping  68 MB          4.1     76T      1Cr+        3+
# 2                   Social  41 MB          4.3    13Cr    100Cr+       12+
# 3  Video Players & Editors  36 MB          4.1     1Cr    100Cr+        3+
# 4                    Tools  12 MB          4.5     41T      1Cr+        3+

# %%
google_apps.loc[3,'Name']='MX Player'

# %%
google_apps
# Out:
#      Rank                               Name  \
# 0       1        Meesho: Online Shopping App
# 1       2            Shopee: Online Shopping
# 2       3                          Instagram
# 3       4                          MX Player
# 4       5                           speedfiy
# ..    ...                                ...
# 595   596                          Cutie SMS
# 596   597  MV Master - MV Master video maker
# 597   598            Amazon Pay For Business
# 598   599          Music Player - MP3 Player
# 599   600         Safe CleanUp - Boost phone
#
#                               Developer                 Category    Size  \
# 0                                Meesho                 Shopping   15 MB
# 1                                Shopee                 Shopping   68 MB
# 2                             Instagram                   Social   41 MB
# 3    MX Media (formerly J2 Interactive)  Video Players & Editors   36 MB
# ...

# %%
google_apps.iloc[3,2]='MX Media'

# %%
google_apps
# Out:
#      Rank                               Name  \
# 0       1        Meesho: Online Shopping App
# 1       2            Shopee: Online Shopping
# 2       3                          Instagram
# 3       4                          MX Player
# 4       5                           speedfiy
# ..    ...                                ...
# 595   596                          Cutie SMS
# 596   597  MV Master - MV Master video maker
# 597   598            Amazon Pay For Business
# 598   599          Music Player - MP3 Player
# 599   600         Safe CleanUp - Boost phone
#
#                              Developer                 Category    Size  \
# 0                               Meesho                 Shopping   15 MB
# 1                               Shopee                 Shopping   68 MB
# 2                            Instagram                   Social   41 MB
# 3                             MX Media  Video Players & Editors   36 MB
# ...

# %%
google_apps.head()
# Out:
#    Rank                         Name                Developer  \
# 0     1  Meesho: Online Shopping App                   Meesho
# 1     2      Shopee: Online Shopping                   Shopee
# 2     3                    Instagram                Instagram
# 3     4                    MX Player                 MX Media
# 4     5                     speedfiy  PRIME DIGITAL PTE. LTD.
#
#                   Category   Size  Star_Rating Reviews Downloads Rated_for
# 0                 Shopping  15 MB          4.4     15L     10Cr+        3+
# 1                 Shopping  68 MB          4.1     76T      1Cr+        3+
# 2                   Social  41 MB          4.3    13Cr    100Cr+       12+
# 3  Video Players & Editors  36 MB          4.1     1Cr    100Cr+        3+
# 4                    Tools  12 MB          4.5     41T      1Cr+        3+

# %%
google_apps.loc[0:3,'Rank'] = [5,6,7,8]

# %%
google_apps
# Out:
#      Rank                               Name  \
# 0       5        Meesho: Online Shopping App
# 1       6            Shopee: Online Shopping
# 2       7                          Instagram
# 3       8                          MX Player
# 4       5                           speedfiy
# ..    ...                                ...
# 595   596                          Cutie SMS
# 596   597  MV Master - MV Master video maker
# 597   598            Amazon Pay For Business
# 598   599          Music Player - MP3 Player
# 599   600         Safe CleanUp - Boost phone
#
#                              Developer                 Category    Size  \
# 0                               Meesho                 Shopping   15 MB
# 1                               Shopee                 Shopping   68 MB
# 2                            Instagram                   Social   41 MB
# 3                             MX Media  Video Players & Editors   36 MB
# ...

# %%
google_apps.loc[google_apps.Name.str.startswith('Google')]
# Out:
#      Rank                            Name   Developer        Category    Size  \
# 11     12                     Google Meet  Google LLC        Business   22 MB
# 28     29  Google Pay: Secure UPI payment  Google LLC         Finance   20 MB
# 85     86               Google Play Games  Google LLC   Entertainment   10 MB
# 141   142                Google Translate  Google LLC           Tools   25 MB
# 199   200                Google Classroom  Google LLC       Education   13 MB
# 217   218           Google Find My Device  Google LLC           Tools  1.8 MB
# 223   224                   Google Photos  Google LLC     Photography   36 MB
# 268   269                   Google Sheets  Google LLC    Productivity   30 MB
# 283   284          Google Opinion Rewards  Google LLC           Tools   11 MB
# 295   296         Google Pay for Business  Google LLC         Finance   21 MB
# 312   313                     Google Home  Google LLC       Lifestyle   19 MB
# ...

# %%
google_apps.head()
# Out:
#    Rank                         Name                Developer  \
# 0     5  Meesho: Online Shopping App                   Meesho
# 1     6      Shopee: Online Shopping                   Shopee
# 2     7                    Instagram                Instagram
# 3     8                    MX Player                 MX Media
# 4     5                     speedfiy  PRIME DIGITAL PTE. LTD.
#
#                   Category   Size  Star_Rating Reviews Downloads Rated_for
# 0                 Shopping  15 MB          4.4     15L     10Cr+        3+
# 1                 Shopping  68 MB          4.1     76T      1Cr+        3+
# 2                   Social  41 MB          4.3    13Cr    100Cr+       12+
# 3  Video Players & Editors  36 MB          4.1     1Cr    100Cr+        3+
# 4                    Tools  12 MB          4.5     41T      1Cr+        3+

# %%
apps_mini = google_apps.iloc[:4,1:5]

# %%
apps_mini
# Out:
#                           Name  Developer                 Category   Size
# 0  Meesho: Online Shopping App     Meesho                 Shopping  15 MB
# 1      Shopee: Online Shopping     Shopee                 Shopping  68 MB
# 2                    Instagram  Instagram                   Social  41 MB
# 3                    MX Player   MX Media  Video Players & Editors  36 MB

# %%
apps_rank = pd.Series([1,2,3,4])

# %%
apps_rank
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
apps_mini.insert(0,'Rank',apps_rank)

# %%
apps_mini
# Out:
#    Rank                         Name  Developer                 Category  \
# 0     1  Meesho: Online Shopping App     Meesho                 Shopping
# 1     2      Shopee: Online Shopping     Shopee                 Shopping
# 2     3                    Instagram  Instagram                   Social
# 3     4                    MX Player   MX Media  Video Players & Editors
#
#     Size
# 0  15 MB
# 1  68 MB
# 2  41 MB
# 3  36 MB

# %%
apps_mini.assign(Reviews=['1Cr','2Cr','3Cr','4Cr'] , Downloads=['10L','1Cr','10Cr','100Cr'])
# Out:
#    Rank                         Name  Developer                 Category  \
# 0     1  Meesho: Online Shopping App     Meesho                 Shopping
# 1     2      Shopee: Online Shopping     Shopee                 Shopping
# 2     3                    Instagram  Instagram                   Social
# 3     4                    MX Player   MX Media  Video Players & Editors
#
#     Size Reviews Downloads
# 0  15 MB     1Cr       10L
# 1  68 MB     2Cr       1Cr
# 2  41 MB     3Cr      10Cr
# 3  36 MB     4Cr     100Cr

# %%
apps_mini
# Out:
#    Rank                         Name  Developer                 Category  \
# 0     1  Meesho: Online Shopping App     Meesho                 Shopping
# 1     2      Shopee: Online Shopping     Shopee                 Shopping
# 2     3                    Instagram  Instagram                   Social
# 3     4                    MX Player   MX Media  Video Players & Editors
#
#     Size
# 0  15 MB
# 1  68 MB
# 2  41 MB
# 3  36 MB

# %%
Dragonball = pd.Series({'Rank':5,'Name':'Dragonball','Developer':'DBZ','Category':'Games','Size':'500 MB'},name=4)

# %%
Dragonball
# Out:
# Rank                  5
# Name         Dragonball
# Developer           DBZ
# Category          Games
# Size             500 MB
# Name: 4, dtype: object

# %%
apps_mini.append(Dragonball)
# Out:
#    Rank                         Name  Developer                 Category  \
# 0     1  Meesho: Online Shopping App     Meesho                 Shopping
# 1     2      Shopee: Online Shopping     Shopee                 Shopping
# 2     3                    Instagram  Instagram                   Social
# 3     4                    MX Player   MX Media  Video Players & Editors
# 4     5                   Dragonball        DBZ                    Games
#
#      Size
# 0   15 MB
# 1   68 MB
# 2   41 MB
# 3   36 MB
# 4  500 MB

# %%
other_apps = pd.DataFrame({'Rank':[6,7],'Name':['PUBG','Temple Run'],'Developer':['Invix','Gameloft'],'Category':['Games','Games']
                          ,'Size':['200 MB','300 MB']})

# %%
other_apps
# Out:
#    Rank        Name Developer Category    Size
# 0     6        PUBG     Invix    Games  200 MB
# 1     7  Temple Run  Gameloft    Games  300 MB

# %%
apps_mini.append(other_apps)
# Out:
#    Rank                         Name  Developer                 Category  \
# 0     1  Meesho: Online Shopping App     Meesho                 Shopping
# 1     2      Shopee: Online Shopping     Shopee                 Shopping
# 2     3                    Instagram  Instagram                   Social
# 3     4                    MX Player   MX Media  Video Players & Editors
# 0     6                         PUBG      Invix                    Games
# 1     7                   Temple Run   Gameloft                    Games
#
#      Size
# 0   15 MB
# 1   68 MB
# 2   41 MB
# 3   36 MB
# 0  200 MB
# 1  300 MB

# %%
apps = pd.read_csv('C:\download\course softwares\DATASETS\Google playstore apps\Google Playstore Apps.csv')

# %%
apps
# Out:
#      Rank                               Name  \
# 0       1        Meesho: Online Shopping App
# 1       2            Shopee: Online Shopping
# 2       3                          Instagram
# 3       4     MX Player: Videos, OTT & Games
# 4       5                           speedfiy
# ..    ...                                ...
# 595   596                          Cutie SMS
# 596   597  MV Master - MV Master video maker
# 597   598            Amazon Pay For Business
# 598   599          Music Player - MP3 Player
# 599   600         Safe CleanUp - Boost phone
#
#                               Developer                 Category    Size  \
# 0                                Meesho                 Shopping   15 MB
# 1                                Shopee                 Shopping   68 MB
# 2                             Instagram                   Social   41 MB
# 3    MX Media (formerly J2 Interactive)  Video Players & Editors   36 MB
# ...

# %%
apps.rename(columns={'Star Rating':'Star_Rating','Rated for':'Rated_for'},inplace=True)

# %%
apps
# Out:
#      Rank                               Name  \
# 0       1        Meesho: Online Shopping App
# 1       2            Shopee: Online Shopping
# 2       3                          Instagram
# 3       4     MX Player: Videos, OTT & Games
# 4       5                           speedfiy
# ..    ...                                ...
# 595   596                          Cutie SMS
# 596   597  MV Master - MV Master video maker
# 597   598            Amazon Pay For Business
# 598   599          Music Player - MP3 Player
# 599   600         Safe CleanUp - Boost phone
#
#                               Developer                 Category    Size  \
# 0                                Meesho                 Shopping   15 MB
# 1                                Shopee                 Shopping   68 MB
# 2                             Instagram                   Social   41 MB
# 3    MX Media (formerly J2 Interactive)  Video Players & Editors   36 MB
# ...

# %%
apps.Name.str.len()
# Out:
# 0      27
# 1      23
# 2       9
# 3      30
# 4       8
#        ..
# 595     9
# 596    33
# 597    23
# 598    25
# 599    26
# Name: Name, Length: 600, dtype: int64

# %%
apps.Name.str.startswith('A')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 595    False
# 596    False
# 597     True
# 598    False
# 599    False
# Name: Name, Length: 600, dtype: bool

# %%
apps.Developer
# Out:
# 0                                  Meesho
# 1                                  Shopee
# 2                               Instagram
# 3      MX Media (formerly J2 Interactive)
# 4                 PRIME DIGITAL PTE. LTD.
#                       ...
# 595                              Info Jod
# 596     MV Master - MV Master video maker
# 597                     Amazon Mobile LLC
# 598                               Apps10X
# 599                             Surf tool
# Name: Developer, Length: 600, dtype: object

# %%
apps.Developer.str.upper()
# Out:
# 0                                  MEESHO
# 1                                  SHOPEE
# 2                               INSTAGRAM
# 3      MX MEDIA (FORMERLY J2 INTERACTIVE)
# 4                 PRIME DIGITAL PTE. LTD.
#                       ...
# 595                              INFO JOD
# 596     MV MASTER - MV MASTER VIDEO MAKER
# 597                     AMAZON MOBILE LLC
# 598                               APPS10X
# 599                             SURF TOOL
# Name: Developer, Length: 600, dtype: object

# %%
apps.Developer.str.lower()
# Out:
# 0                                  meesho
# 1                                  shopee
# 2                               instagram
# 3      mx media (formerly j2 interactive)
# 4                 prime digital pte. ltd.
#                       ...
# 595                              info jod
# 596     mv master - mv master video maker
# 597                     amazon mobile llc
# 598                               apps10x
# 599                             surf tool
# Name: Developer, Length: 600, dtype: object

# %%
apps.Developer.str.swapcase()
# Out:
# 0                                  mEESHO
# 1                                  sHOPEE
# 2                               iNSTAGRAM
# 3      mx mEDIA (FORMERLY j2 iNTERACTIVE)
# 4                 prime digital pte. ltd.
#                       ...
# 595                              iNFO jOD
# 596     mv mASTER - mv mASTER VIDEO MAKER
# 597                     aMAZON mOBILE llc
# 598                               aPPS10x
# 599                             sURF TOOL
# Name: Developer, Length: 600, dtype: object

# %%
apps.Developer.str.capitalize()
# Out:
# 0                                  Meesho
# 1                                  Shopee
# 2                               Instagram
# 3      Mx media (formerly j2 interactive)
# 4                 Prime digital pte. ltd.
#                       ...
# 595                              Info jod
# 596     Mv master - mv master video maker
# 597                     Amazon mobile llc
# 598                               Apps10x
# 599                             Surf tool
# Name: Developer, Length: 600, dtype: object

# %%
apps.Name.str.find('Music').value_counts()
# Out:
# -1     582
#  5       3
#  6       3
#  0       3
#  3       1
#  7       1
#  8       1
#  9       1
#  10      1
#  12      1
#  16      1
#  21      1
#  36      1
# Name: Name, dtype: int64

# %%
apps.head()
# Out:
#    Rank                            Name                           Developer  \
# 0     1     Meesho: Online Shopping App                              Meesho
# 1     2         Shopee: Online Shopping                              Shopee
# 2     3                       Instagram                           Instagram
# 3     4  MX Player: Videos, OTT & Games  MX Media (formerly J2 Interactive)
# 4     5                        speedfiy             PRIME DIGITAL PTE. LTD.
#
#                   Category   Size  Star_Rating Reviews Downloads Rated_for
# 0                 Shopping  15 MB          4.4     15L     10Cr+        3+
# 1                 Shopping  68 MB          4.1     76T      1Cr+        3+
# 2                   Social  41 MB          4.3    13Cr    100Cr+       12+
# 3  Video Players & Editors  36 MB          4.1     1Cr    100Cr+        3+
# 4                    Tools  12 MB          4.5     41T      1Cr+        3+

# %%
apps.Name.iloc[0:2].str.strip()
# Out:
# 0    Meesho: Online Shopping App
# 1        Shopee: Online Shopping
# Name: Name, dtype: object

# %%
apps.head()
# Out:
#    Rank                            Name                           Developer  \
# 0     1     Meesho: Online Shopping App                              Meesho
# 1     2         Shopee: Online Shopping                              Shopee
# 2     3                       Instagram                           Instagram
# 3     4  MX Player: Videos, OTT & Games  MX Media (formerly J2 Interactive)
# 4     5                        speedfiy             PRIME DIGITAL PTE. LTD.
#
#                   Category   Size  Star_Rating Reviews Downloads Rated_for
# 0                 Shopping  15 MB          4.4     15L     10Cr+        3+
# 1                 Shopping  68 MB          4.1     76T      1Cr+        3+
# 2                   Social  41 MB          4.3    13Cr    100Cr+       12+
# 3  Video Players & Editors  36 MB          4.1     1Cr    100Cr+        3+
# 4                    Tools  12 MB          4.5     41T      1Cr+        3+

# %%
apps.Name.str.split('- ')
# Out:
# 0            [Meesho: Online Shopping App]
# 1                [Shopee: Online Shopping]
# 2                              [Instagram]
# 3         [MX Player: Videos, OTT & Games]
# 4                               [speedfiy]
#                       ...
# 595                            [Cutie SMS]
# 596    [MV Master , MV Master video maker]
# 597              [Amazon Pay For Business]
# 598            [Music Player , MP3 Player]
# 599           [Safe CleanUp , Boost phone]
# Name: Name, Length: 600, dtype: object

# %%
apps.Name.str.split('- ').str.get(0)
# Out:
# 0         Meesho: Online Shopping App
# 1             Shopee: Online Shopping
# 2                           Instagram
# 3      MX Player: Videos, OTT & Games
# 4                            speedfiy
#                     ...
# 595                         Cutie SMS
# 596                        MV Master
# 597           Amazon Pay For Business
# 598                     Music Player
# 599                     Safe CleanUp
# Name: Name, Length: 600, dtype: object

# %%
apps.Name
# Out:
# 0            Meesho: Online Shopping App
# 1                Shopee: Online Shopping
# 2                              Instagram
# 3         MX Player: Videos, OTT & Games
# 4                               speedfiy
#                      ...
# 595                            Cutie SMS
# 596    MV Master - MV Master video maker
# 597              Amazon Pay For Business
# 598            Music Player - MP3 Player
# 599           Safe CleanUp - Boost phone
# Name: Name, Length: 600, dtype: object

# %%
apps.Name.str.split(': ',expand=True)
# Out:
#                                      0                    1
# 0                               Meesho  Online Shopping App
# 1                               Shopee      Online Shopping
# 2                            Instagram                 None
# 3                            MX Player  Videos, OTT & Games
# 4                             speedfiy                 None
# ..                                 ...                  ...
# 595                          Cutie SMS                 None
# 596  MV Master - MV Master video maker                 None
# 597            Amazon Pay For Business                 None
# 598          Music Player - MP3 Player                 None
# 599         Safe CleanUp - Boost phone                 None
#
# [600 rows x 2 columns]

# %%
apps[['First Word','Second Word']] = apps.Name.str.split(': ',expand=True)

# %%
apps
# Out:
#      Rank                               Name  \
# 0       1        Meesho: Online Shopping App
# 1       2            Shopee: Online Shopping
# 2       3                          Instagram
# 3       4     MX Player: Videos, OTT & Games
# 4       5                           speedfiy
# ..    ...                                ...
# 595   596                          Cutie SMS
# 596   597  MV Master - MV Master video maker
# 597   598            Amazon Pay For Business
# 598   599          Music Player - MP3 Player
# 599   600         Safe CleanUp - Boost phone
#
#                               Developer                 Category    Size  \
# 0                                Meesho                 Shopping   15 MB
# 1                                Shopee                 Shopping   68 MB
# 2                             Instagram                   Social   41 MB
# 3    MX Media (formerly J2 Interactive)  Video Players & Editors   36 MB
# ...

# %%
apps['Second Word'].str.find('Shopping').value_counts()
# Out:
# -1.0    117
#  7.0      6
# Name: Second Word, dtype: int64

# %%
Player = apps.Name.str.contains('Player')

# %%
four_plus = apps.Star_Rating>=4

# %%
apps.loc[Player & four_plus]
# Out:
#      Rank                                          Name  \
# 3       4                MX Player: Videos, OTT & Games
# 29     30                PLAYit-All in One Video Player
# 163   164                 MX Player Online: OTT & Games
# 490   491  Pi Music Player - MP3 Player & YouTube Music
# 501   502         Music Player - MP3 Player, Play Music
# 598   599                     Music Player - MP3 Player
#
#                               Developer                 Category    Size  \
# 3    MX Media (formerly J2 Interactive)  Video Players & Editors   36 MB
# 29          PLAYIT TECHNOLOGY PTE. LTD.  Video Players & Editors   14 MB
# 163  MX Media (formerly J2 Interactive)            Entertainment   26 MB
# 490             Musicophilia Music Apps            Music & Audio  9.1 MB
# 501                         InShot Inc.            Music & Audio   16 MB
# 598                             Apps10X            Music & Audio  9.4 MB
#
#      Star_Rating Reviews Downloads Rated_for  \
# ...

# %%
apps.head()
# Out:
#    Rank                            Name                           Developer  \
# 0     1     Meesho: Online Shopping App                              Meesho
# 1     2         Shopee: Online Shopping                              Shopee
# 2     3                       Instagram                           Instagram
# 3     4  MX Player: Videos, OTT & Games  MX Media (formerly J2 Interactive)
# 4     5                        speedfiy             PRIME DIGITAL PTE. LTD.
#
#                   Category   Size  Star_Rating Reviews Downloads Rated_for  \
# 0                 Shopping  15 MB          4.4     15L     10Cr+        3+
# 1                 Shopping  68 MB          4.1     76T      1Cr+        3+
# 2                   Social  41 MB          4.3    13Cr    100Cr+       12+
# 3  Video Players & Editors  36 MB          4.1     1Cr    100Cr+        3+
# 4                    Tools  12 MB          4.5     41T      1Cr+        3+
#
#   First Word          Second Word
# ...

# %%
apps.Name.str.split(expand=True)
# Out:
#             0        1         2         3       4      5      6     7     8   \
# 0      Meesho:   Online  Shopping       App    None   None   None  None  None
# 1      Shopee:   Online  Shopping      None    None   None   None  None  None
# 2    Instagram     None      None      None    None   None   None  None  None
# 3           MX  Player:   Videos,       OTT       &  Games   None  None  None
# 4     speedfiy     None      None      None    None   None   None  None  None
# ..         ...      ...       ...       ...     ...    ...    ...   ...   ...
# 595      Cutie      SMS      None      None    None   None   None  None  None
# 596         MV   Master         -        MV  Master  video  maker  None  None
# 597     Amazon      Pay       For  Business    None   None   None  None  None
# 598      Music   Player         -       MP3  Player   None   None  None  None
# 599       Safe  CleanUp         -     Boost   phone   None   None  None  None
#
#        9     10
# ...

# %%
apps.head()
# Out:
#    Rank                            Name                           Developer  \
# 0     1     Meesho: Online Shopping App                              Meesho
# 1     2         Shopee: Online Shopping                              Shopee
# 2     3                       Instagram                           Instagram
# 3     4  MX Player: Videos, OTT & Games  MX Media (formerly J2 Interactive)
# 4     5                        speedfiy             PRIME DIGITAL PTE. LTD.
#
#                   Category   Size  Star_Rating Reviews Downloads Rated_for  \
# 0                 Shopping  15 MB          4.4     15L     10Cr+        3+
# 1                 Shopping  68 MB          4.1     76T      1Cr+        3+
# 2                   Social  41 MB          4.3    13Cr    100Cr+       12+
# 3  Video Players & Editors  36 MB          4.1     1Cr    100Cr+        3+
# 4                    Tools  12 MB          4.5     41T      1Cr+        3+
#
#   First Word          Second Word
# ...

# %%
import matplotlib.pyplot as plt

# %%
apps.plot();

# %%
apps.head()
# Out:
#    Rank                            Name                           Developer  \
# 0     1     Meesho: Online Shopping App                              Meesho
# 1     2         Shopee: Online Shopping                              Shopee
# 2     3                       Instagram                           Instagram
# 3     4  MX Player: Videos, OTT & Games  MX Media (formerly J2 Interactive)
# 4     5                        speedfiy             PRIME DIGITAL PTE. LTD.
#
#                   Category   Size  Star_Rating Reviews Downloads Rated_for  \
# 0                 Shopping  15 MB          4.4     15L     10Cr+        3+
# 1                 Shopping  68 MB          4.1     76T      1Cr+        3+
# 2                   Social  41 MB          4.3    13Cr    100Cr+       12+
# 3  Video Players & Editors  36 MB          4.1     1Cr    100Cr+        3+
# 4                    Tools  12 MB          4.5     41T      1Cr+        3+
#
#   First Word          Second Word
# ...

# %%
apps.Star_Rating.value_counts().plot();

# %%
app = apps.Star_Rating.value_counts(sort=False).plot(kind='bar',figsize=(12,6))
app.set_label('Rating')
app.set_label('No of Apps')

# %%
app = apps.Star_Rating.value_counts(sort=False).plot(kind='barh',figsize=(12,12))
app.set_label('Rating')
app.set_label('No of Apps')

# %%
apps.Star_Rating
# Out:
# 0      4.4
# 1      4.1
# 2      4.3
# 3      4.1
# 4      4.5
#       ...
# 595    4.9
# 596    3.6
# 597    4.3
# 598    4.6
# 599    4.0
# Name: Star_Rating, Length: 600, dtype: float64

# %%
apps.groupby('Category').Rank.sum().plot(kind='pie',figsize=(15,15));

# %%
apps.head()
# Out:
#    Rank                            Name                           Developer  \
# 0     1     Meesho: Online Shopping App                              Meesho
# 1     2         Shopee: Online Shopping                              Shopee
# 2     3                       Instagram                           Instagram
# 3     4  MX Player: Videos, OTT & Games  MX Media (formerly J2 Interactive)
# 4     5                        speedfiy             PRIME DIGITAL PTE. LTD.
#
#                   Category   Size  Star_Rating Reviews Downloads Rated_for  \
# 0                 Shopping  15 MB          4.4     15L     10Cr+        3+
# 1                 Shopping  68 MB          4.1     76T      1Cr+        3+
# 2                   Social  41 MB          4.3    13Cr    100Cr+       12+
# 3  Video Players & Editors  36 MB          4.1     1Cr    100Cr+        3+
# 4                    Tools  12 MB          4.5     41T      1Cr+        3+
#
#   First Word          Second Word
# ...

# %%
app = apps.Star_Rating.plot(kind='hist')
app.set_xlabel('Ratings');

# %%
app = apps.Star_Rating.plot(kind='hist',bins=5,orientation='horizontal')
app.set_label('Ratings')

# %%
Business_apps = apps.loc[apps.Category=='Business',['Name','Star_Rating']].groupby('Name').sum()

# %%
Business_apps
# Out:
#                                                     Star_Rating
# Name
# Adobe Scan: PDF Scanner, OCR                                4.6
# Amazon Pay For Business                                     4.3
# AnyDesk Remote Desktop Software                             3.6
# Bikayi: Whatsapp Catalogue and Make Business Easy           4.7
# Camera Scanner: PDF Scanner, PDF Creator, Scanner           4.3
# Dhani Card with Credit & Store                              4.3
# Google Meet                                                 4.1
# Hirect - Startup Jobs & Hiring                              4.6
# Khata Book Udhar Bahi Khata, Credit Ledger Account          4.6
# Kisan App, Khetiwadi, Pashu Mela: Krishify                  4.2
# Legion Network                                              4.5
# LinkedIn: Jobs & Business News                              4.3
# Microsoft Teams                                             4.3
# Naukri.com Job Search App                                   4.6
# ...

# %%
Business_apps.nlargest(20,columns='Star_Rating').plot(kind='barh',figsize=(10,10));
# Out:
# C:\Users\virat\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 2327 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\virat\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 2366 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\virat\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 2351 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\virat\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 2349 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\virat\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 2376 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
