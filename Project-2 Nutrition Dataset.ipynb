# %%
import pandas as pd
import numpy as np

# %%
nutrition = pd.read_csv('C:/download/course softwares/The Ultimate Pandas Bootcamp Advanced Python Data Analysis/python practice files/Sources/nutrition.csv')

# %%
nutrition
# Out:
#       Unnamed: 0                                               name  \
# 0              0                                         Cornstarch
# 1              1                                       Nuts, pecans
# 2              2                                      Eggplant, raw
# 3              3                                     Teff, uncooked
# 4              4                                    Sherbet, orange
# ...          ...                                                ...
# 8784        8784  Beef, raw, all grades, trimmed to 0" fat, sepa...
# 8785        8785  Lamb, cooked, separable lean only, composite o...
# 8786        8786  Lamb, raw, separable lean and fat, composite o...
# 8787        8787  Beef, raw, all grades, trimmed to 0" fat, sepa...
# 8788        8788  Beef, raw, all grades, trimmed to 0" fat, sepa...
#
#      serving_size  calories total_fat saturated_fat cholesterol    sodium  \
# 0           100 g       381      0.1g           NaN           0   9.00 mg
# ...

# %%
nutrition.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8789 entries, 0 to 8788
# Columns: 77 entries, Unnamed: 0 to water
# dtypes: int64(3), object(74)
# memory usage: 5.2+ MB

# %%
nutrition = nutrition.drop('Unnamed: 0',axis=1)

# %%
nutrition.head()
# Out:
#               name serving_size  calories total_fat saturated_fat cholesterol  \
# 0       Cornstarch        100 g       381      0.1g           NaN           0
# 1     Nuts, pecans        100 g       691       72g          6.2g           0
# 2    Eggplant, raw        100 g        25      0.2g           NaN           0
# 3   Teff, uncooked        100 g       367      2.4g          0.4g           0
# 4  Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#      sodium  choline     folate folic_acid  ...      fat  \
# 0   9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  ...   0.05 g
# 1   0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  ...  71.97 g
# 2   2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  ...   0.18 g
# 3  12.00 mg  13.1 mg          0          0  ...   2.38 g
# 4  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  ...   2.00 g
#
#   saturated_fatty_acids monounsaturated_fatty_acids  \
# 0               0.009 g                     0.016 g
# ...

# %%
nutrition.sample(3)
# Out:
#                                                    name serving_size  \
# 3052         McDONALD'S, Southern Style Chicken Biscuit        100 g
# 2912        Kale, without salt, drained, boiled, cooked        100 g
# 5117  Seeds, without salt, oil roasted, sunflower se...        100 g
#
#       calories total_fat saturated_fat cholesterol     sodium  choline  \
# 3052       304       15g          5.7g           0  868.00 mg        0
# 2912        28      0.4g          0.1g           0   23.00 mg   0.4 mg
# 5117       592       51g          7.1g           0    3.00 mg  55.1 mg
#
#           folate folic_acid  ...      fat saturated_fatty_acids  \
# 3052   64.00 mcg          0  ...  14.93 g               5.712 g
# 2912   13.00 mcg   0.00 mcg  ...   0.40 g               0.052 g
# 5117  234.00 mcg   0.00 mcg  ...  51.30 g               7.068 g
#
#      monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 3052                     5.455 g                     3.308 g
# ...

# %%
nutrition.axes[1]
# Out:
# Index(['name', 'serving_size', 'calories', 'total_fat', 'saturated_fat',
#        'cholesterol', 'sodium', 'choline', 'folate', 'folic_acid', 'niacin',
#        'pantothenic_acid', 'riboflavin', 'thiamin', 'vitamin_a',
#        'vitamin_a_rae', 'carotene_alpha', 'carotene_beta',
#        'cryptoxanthin_beta', 'lutein_zeaxanthin', 'lucopene', 'vitamin_b12',
#        'vitamin_b6', 'vitamin_c', 'vitamin_d', 'vitamin_e', 'tocopherol_alpha',
#        'vitamin_k', 'calcium', 'copper', 'irom', 'magnesium', 'manganese',
#        'phosphorous', 'potassium', 'selenium', 'zink', 'protein', 'alanine',
#        'arginine', 'aspartic_acid', 'cystine', 'glutamic_acid', 'glycine',
#        'histidine', 'hydroxyproline', 'isoleucine', 'leucine', 'lysine',
#        'methionine', 'phenylalanine', 'proline', 'serine', 'threonine',
#        'tryptophan', 'tyrosine', 'valine', 'carbohydrate', 'fiber', 'sugars',
#        'fructose', 'galactose', 'glucose', 'lactose', 'maltose', 'sucrose',
# ...

# %%
nutrition.axes[1][70]
# Out:
# 'fatty_acids_total_trans'

# %%
nutrition = nutrition.set_index('name')

# %%
nutrition.head()
# Out:
#                 serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch             100 g       381      0.1g           NaN           0
# Nuts, pecans           100 g       691       72g          6.2g           0
# Eggplant, raw          100 g        25      0.2g           NaN           0
# Teff, uncooked         100 g       367      2.4g          0.4g           0
# Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#                    sodium  choline     folate folic_acid    niacin  ...  \
# name                                                                ...
# Cornstarch        9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  0.000 mg  ...
# Nuts, pecans      0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  1.167 mg  ...
# Eggplant, raw     2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  0.649 mg  ...
# Teff, uncooked   12.00 mg  13.1 mg          0          0  3.363 mg  ...
# Sherbet, orange  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  0.063 mg  ...
#
# ...

# %%
nutrition.set_index('folic_acid')
# Out:
#            serving_size  calories total_fat saturated_fat cholesterol  \
# folic_acid
# 0.00 mcg          100 g       381      0.1g           NaN           0
# 0.00 mcg          100 g       691       72g          6.2g           0
# 0.00 mcg          100 g        25      0.2g           NaN           0
# 0                 100 g       367      2.4g          0.4g           0
# 0.00 mcg          100 g       144        2g          1.2g         1mg
# ...                 ...       ...       ...           ...         ...
# 0.00 mcg          100 g       125      3.5g          1.4g        62mg
# 0.00 mcg          100 g       206      8.9g          3.9g       109mg
# 0.00 mcg          100 g       277       23g           12g        78mg
# 0.00 mcg          100 g       121        3g          1.1g        60mg
# 0.00 mcg          100 g       121        3g          1.1g        60mg
#
#               sodium  choline     folate    niacin pantothenic_acid  ...  \
# ...

# %%
nutrition.set_index('folic_acid',append=True)
# Out:
#                                                               serving_size  \
# name                                               folic_acid
# Cornstarch                                         0.00 mcg          100 g
# Nuts, pecans                                       0.00 mcg          100 g
# Eggplant, raw                                      0.00 mcg          100 g
# Teff, uncooked                                     0                 100 g
# Sherbet, orange                                    0.00 mcg          100 g
# ...                                                                    ...
# Beef, raw, all grades, trimmed to 0" fat, separ... 0.00 mcg          100 g
# Lamb, cooked, separable lean only, composite of... 0.00 mcg          100 g
# Lamb, raw, separable lean and fat, composite of... 0.00 mcg          100 g
# Beef, raw, all grades, trimmed to 0" fat, separ... 0.00 mcg          100 g
# Beef, raw, all grades, trimmed to 0" fat, separ... 0.00 mcg          100 g
#
# ...

# %%
nutrition.calories.value_counts()
# Out:
# 884    78
# 47     45
# 56     43
# 0      39
# 50     38
#        ..
# 897     1
# 685     1
# 669     1
# 605     1
# 727     1
# Name: calories, Length: 671, dtype: int64

# %%
nutrition.loc['Eggplant, raw':'Sherbet, orange','calories':'cholesterol']
# Out:
#                  calories total_fat saturated_fat cholesterol
# name
# Eggplant, raw          25      0.2g           NaN           0
# Teff, uncooked        367      2.4g          0.4g           0
# Sherbet, orange       144        2g          1.2g         1mg

# %%
nutrition.loc[['Teff, uncooked','Sherbet, orange'] , ['sodium','choline','fat']]
# Out:
#                    sodium  choline     fat
# name
# Teff, uncooked   12.00 mg  13.1 mg  2.38 g
# Sherbet, orange  46.00 mg   7.7 mg  2.00 g

# %%
nutrition.iloc[3]
# Out:
# serving_size      100 g
# calories            367
# total_fat          2.4g
# saturated_fat      0.4g
# cholesterol           0
#                   ...
# alcohol               0
# ash              2.37 g
# caffeine              0
# theobromine           0
# water            8.82 g
# Name: Teff, uncooked, Length: 75, dtype: object

# %%
nutrition.iloc[[4,6,7]]
# Out:
#                   serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Sherbet, orange          100 g       144        2g          1.2g         1mg
# Taro leaves, raw         100 g        42      0.7g          0.2g           0
# Lamb, raw, ground        100 g       282       23g           10g        73mg
#
#                      sodium  choline      folate folic_acid    niacin  ...  \
# name                                                                   ...
# Sherbet, orange    46.00 mg   7.7 mg    4.00 mcg   0.00 mcg  0.063 mg  ...
# Taro leaves, raw    3.00 mg  12.8 mg  126.00 mcg   0.00 mcg  1.513 mg  ...
# Lamb, raw, ground  59.00 mg  69.3 mg   18.00 mcg   0.00 mcg  5.960 mg  ...
#
#                        fat saturated_fatty_acids monounsaturated_fatty_acids  \
# name
# Sherbet, orange     2.00 g               1.160 g                     0.530 g
# Taro leaves, raw    0.74 g               0.151 g                     0.060 g
# ...

# %%
nutrition.iloc[[4,6,7],2:5]
# Out:
#                   total_fat saturated_fat cholesterol
# name
# Sherbet, orange          2g          1.2g         1mg
# Taro leaves, raw       0.7g          0.2g           0
# Lamb, raw, ground       23g           10g        73mg

# %%
nutrition.iloc[9,1]
# Out:
# 290

# %%
nutrition.head()
# Out:
#                 serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch             100 g       381      0.1g           NaN           0
# Nuts, pecans           100 g       691       72g          6.2g           0
# Eggplant, raw          100 g        25      0.2g           NaN           0
# Teff, uncooked         100 g       367      2.4g          0.4g           0
# Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#                    sodium  choline     folate folic_acid    niacin  ...  \
# name                                                                ...
# Cornstarch        9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  0.000 mg  ...
# Nuts, pecans      0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  1.167 mg  ...
# Eggplant, raw     2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  0.649 mg  ...
# Teff, uncooked   12.00 mg  13.1 mg          0          0  3.363 mg  ...
# Sherbet, orange  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  0.063 mg  ...
#
# ...

# %%
nutrition.at['Nuts, pecans','calories']
# Out:
# 691

# %%
nutrition.iat[1,1]
# Out:
# 691

# %%
nutr_mini = nutrition.sample(10)

# %%
nutr_mini
# Out:
#                                                    serving_size  calories  \
# name
# Peas, raw, edible-podded                                  100 g        42
# Vegetable juice cocktail, canned                          100 g        22
# Fish, dry heat, cooked, florida, pompano                  100 g       211
# WORTHINGTON Prosage Roll, unprepared, frozen              100 g       261
# Candies, TWIZZLERS Strawberry Twists Candy                100 g       348
# Grape juice, with added ascorbic acid and calci...        100 g        62
# Sauce, with salt, bottled, tomato chili sauce             100 g        92
# Pork, roasted, separable lean only, whole, ham,...        100 g       157
# Veal, grilled, cooked, separable lean only, cho...        100 g       159
# Tortillas, shelf stable, flour, ready-to-bake o...        100 g       297
#
#                                                    total_fat saturated_fat  \
# name
# ...

# %%
nutr_mini.loc[:,['total_fat','cholesterol']]
# Out:
#                                                    total_fat cholesterol
# name
# Peas, raw, edible-podded                                0.2g           0
# Vegetable juice cocktail, canned                        0.3g           0
# Fish, dry heat, cooked, florida, pompano                 12g        64mg
# WORTHINGTON Prosage Roll, unprepared, frozen             18g         2mg
# Candies, TWIZZLERS Strawberry Twists Candy              2.3g           0
# Grape juice, with added ascorbic acid and calci...      0.1g           0
# Sauce, with salt, bottled, tomato chili sauce           0.3g           0
# Pork, roasted, separable lean only, whole, ham,...      5.5g        55mg
# Veal, grilled, cooked, separable lean only, cho...      4.4g        78mg
# Tortillas, shelf stable, flour, ready-to-bake o...      7.6g           0

# %%
b12 = nutr_mini.columns.get_loc('vitamin_b12')

# %%
nutr_mini.iloc[0:3,b12:]
# Out:
#                                          vitamin_b12 vitamin_b6 vitamin_c  \
# name
# Peas, raw, edible-podded                    0.00 mcg   0.160 mg   60.0 mg
# Vegetable juice cocktail, canned            0.00 mcg   0.071 mg   54.3 mg
# Fish, dry heat, cooked, florida, pompano    1.20 mcg   0.230 mg    0.0 mg
#
#                                          vitamin_d vitamin_e tocopherol_alpha  \
# name
# Peas, raw, edible-podded                   0.00 IU   0.39 mg          0.39 mg
# Vegetable juice cocktail, canned           0.00 IU   1.02 mg          1.02 mg
# Fish, dry heat, cooked, florida, pompano         0         0                0
#
#                                          vitamin_k   calcium    copper  \
# name
# Peas, raw, edible-podded                  25.0 mcg  43.00 mg  0.079 mg
# Vegetable juice cocktail, canned           6.1 mcg  14.00 mg  0.068 mg
# Fish, dry heat, cooked, florida, pompano         0  43.00 mg  0.078 mg
#
# ...

# %%
nutr_mini.head()
# Out:
#                                              serving_size  calories total_fat  \
# name
# Peas, raw, edible-podded                            100 g        42      0.2g
# Vegetable juice cocktail, canned                    100 g        22      0.3g
# Fish, dry heat, cooked, florida, pompano            100 g       211       12g
# WORTHINGTON Prosage Roll, unprepared, frozen        100 g       261       18g
# Candies, TWIZZLERS Strawberry Twists Candy          100 g       348      2.3g
#
#                                              saturated_fat cholesterol  \
# name
# Peas, raw, edible-podded                               NaN           0
# Vegetable juice cocktail, canned                      0.1g           0
# Fish, dry heat, cooked, florida, pompano              4.5g        64mg
# WORTHINGTON Prosage Roll, unprepared, frozen          3.4g         2mg
# Candies, TWIZZLERS Strawberry Twists Candy             NaN           0
#
# ...

# %%
nutr_mini.iloc[2,1]
# Out:
# 211

# %%
nutrition.head()
# Out:
#                 serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch             100 g       381      0.1g           NaN           0
# Nuts, pecans           100 g       691       72g          6.2g           0
# Eggplant, raw          100 g        25      0.2g           NaN           0
# Teff, uncooked         100 g       367      2.4g          0.4g           0
# Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#                    sodium  choline     folate folic_acid    niacin  ...  \
# name                                                                ...
# Cornstarch        9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  0.000 mg  ...
# Nuts, pecans      0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  1.167 mg  ...
# Eggplant, raw     2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  0.649 mg  ...
# Teff, uncooked   12.00 mg  13.1 mg          0          0  3.363 mg  ...
# Sherbet, orange  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  0.063 mg  ...
#
# ...

# %%
units = nutrition.astype(str).replace('[^a-zA-Z]','',regex=True)

# %%
units.saturated_fat.value_counts()
# Out:
# g      7199
# nan    1590
# Name: saturated_fat, dtype: int64

# %%
df = pd.DataFrame({'age':[10,20,30,40] , 'weight':[40.1,50.1,60.1,70.1] , 'height':[1.5,2.5,3.5,4.5]})

# %%
df = df.astype(float)

# %%
df
# Out:
#     age  weight  height
# 0  10.0    40.1     1.5
# 1  20.0    50.1     2.5
# 2  30.0    60.1     3.5
# 3  40.0    70.1     4.5

# %%
df.rename(columns={'weight':'Weight(kg)','height':'Height(m)'} , index = {0:'A',1:'B'})
# Out:
#     age  Weight(kg)  Height(m)
# A  10.0        40.1        1.5
# B  20.0        50.1        2.5
# 2  30.0        60.1        3.5
# 3  40.0        70.1        4.5

# %%
units
# Out:
#                                                    serving_size calories  \
# name
# Cornstarch                                                    g
# Nuts, pecans                                                  g
# Eggplant, raw                                                 g
# Teff, uncooked                                                g
# Sherbet, orange                                               g
# ...                                                         ...      ...
# Beef, raw, all grades, trimmed to 0" fat, separ...            g
# Lamb, cooked, separable lean only, composite of...            g
# Lamb, raw, separable lean and fat, composite of...            g
# Beef, raw, all grades, trimmed to 0" fat, separ...            g
# Beef, raw, all grades, trimmed to 0" fat, separ...            g
#
#                                                    total_fat saturated_fat  \
# name
# Cornstarch                                                 g           nan
# ...

# %%
nutrition.head()
# Out:
#                 serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch             100 g       381      0.1g           NaN           0
# Nuts, pecans           100 g       691       72g          6.2g           0
# Eggplant, raw          100 g        25      0.2g           NaN           0
# Teff, uncooked         100 g       367      2.4g          0.4g           0
# Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#                    sodium  choline     folate folic_acid    niacin  ...  \
# name                                                                ...
# Cornstarch        9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  0.000 mg  ...
# Nuts, pecans      0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  1.167 mg  ...
# Eggplant, raw     2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  0.649 mg  ...
# Teff, uncooked   12.00 mg  13.1 mg          0          0  3.363 mg  ...
# Sherbet, orange  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  0.063 mg  ...
#
# ...

# %%
nutrition = nutrition.replace('[a-zA-Z]','',regex=True)

# %%
nutrition = nutrition.astype(float)

# %%
nutrition
# Out:
#                                                     serving_size  calories  \
# name
# Cornstarch                                                 100.0     381.0
# Nuts, pecans                                               100.0     691.0
# Eggplant, raw                                              100.0      25.0
# Teff, uncooked                                             100.0     367.0
# Sherbet, orange                                            100.0     144.0
# ...                                                          ...       ...
# Beef, raw, all grades, trimmed to 0" fat, separ...         100.0     125.0
# Lamb, cooked, separable lean only, composite of...         100.0     206.0
# Lamb, raw, separable lean and fat, composite of...         100.0     277.0
# Beef, raw, all grades, trimmed to 0" fat, separ...         100.0     121.0
# Beef, raw, all grades, trimmed to 0" fat, separ...         100.0     121.0
#
# ...

# %%
nutrition.filter(regex = '[Oo]ctopus',axis=0)
# Out:
#                                                serving_size  calories  \
# name
# Octopus (Alaska Native)                               100.0      56.0
# Mollusks, raw, common, octopus                        100.0      82.0
# Mollusks, moist heat, cooked, common, octopus         100.0     164.0
#
#                                                total_fat  saturated_fat  \
# name
# Octopus (Alaska Native)                              0.8            0.2
# Mollusks, raw, common, octopus                       1.0            0.2
# Mollusks, moist heat, cooked, common, octopus        2.1            0.5
#
#                                                cholesterol  sodium  choline  \
# name
# Octopus (Alaska Native)                               41.0     0.0      0.0
# Mollusks, raw, common, octopus                        48.0   230.0     65.0
# Mollusks, moist heat, cooked, common, octopus         96.0   460.0     81.0
#
# ...

# %%
nutrition.filter(regex = '[Oo]ctopus',axis=0)\
         .loc[:,['cholesterol','serving_size','calories']]
# Out:
#                                                cholesterol  serving_size  \
# name
# Octopus (Alaska Native)                               41.0         100.0
# Mollusks, raw, common, octopus                        48.0         100.0
# Mollusks, moist heat, cooked, common, octopus         96.0         100.0
#
#                                                calories
# name
# Octopus (Alaska Native)                            56.0
# Mollusks, raw, common, octopus                     82.0
# Mollusks, moist heat, cooked, common, octopus     164.0

# %%
nutrition.sort_values(['cholesterol','sodium'] , ascending=[False,True])
# Out:
#                                                     serving_size  calories  \
# name
# Beef, simmered, cooked, brain, variety meats an...         100.0     151.0
# Veal, braised, cooked, brain, variety meats and...         100.0     136.0
# Beef, raw, brain, variety meats and by-products            100.0     143.0
# Lamb, soaked and fried, cooked, brains, importe...         100.0     154.0
# Pork, braised, cooked, brain, variety meats and...         100.0     138.0
# ...                                                          ...       ...
# Leavening agents, sodium aluminum sulfate, doub...         100.0      53.0
# Seasoning mix, coriander & annatto, sazon, dry             100.0       0.0
# Desserts, unsweetened, tablets, rennin                     100.0      84.0
# Leavening agents, baking soda                              100.0       0.0
# Salt, table                                                100.0       0.0
#
# ...

# %%
nutrition[nutrition.calories.between(20,60)]
# Out:
#                                                     serving_size  calories  \
# name
# Eggplant, raw                                              100.0      25.0
# Cauliflower, raw                                           100.0      25.0
# Taro leaves, raw                                           100.0      42.0
# PACE, Picante Sauce                                        100.0      25.0
# Mango nectar, canned                                       100.0      51.0
# ...                                                          ...       ...
# Beverages, added calcium, high vitamin C, great...         100.0      29.0
# Ruby Red grapefruit juice blend (grapefruit, gr...         100.0      44.0
# Beverages, prepared with water, frozen concentr...         100.0      45.0
# Apple juice, diluted with 3 volume water withou...         100.0      47.0
# Apple juice, with added ascorbic acid, diluted ...         100.0      47.0
#
# ...

# %%
nutrition.min(axis=1)
# Out:
# name
# Cornstarch                                                                                            0.0
# Nuts, pecans                                                                                          0.0
# Eggplant, raw                                                                                         0.0
# Teff, uncooked                                                                                        0.0
# Sherbet, orange                                                                                       0.0
#                                                                                                      ...
# Beef, raw, all grades, trimmed to 0" fat, separable lean and fat, boneless, top round roast, round    0.0
# Lamb, cooked, separable lean only, composite of trimmed retail cuts, frozen, imported, New Zealand    0.0
# Lamb, raw, separable lean and fat, composite of trimmed retail cuts, frozen, imported, New Zealand    0.0
# ...

# %%
nutrition.max(axis=1)
# Out:
# name
# Cornstarch                                                                                            381.0
# Nuts, pecans                                                                                          691.0
# Eggplant, raw                                                                                         229.0
# Teff, uncooked                                                                                        429.0
# Sherbet, orange                                                                                       144.0
#                                                                                                       ...
# Beef, raw, all grades, trimmed to 0" fat, separable lean and fat, boneless, top round roast, round    311.0
# Lamb, cooked, separable lean only, composite of trimmed retail cuts, frozen, imported, New Zealand    246.0
# Lamb, raw, separable lean and fat, composite of trimmed retail cuts, frozen, imported, New Zealand    277.0
# ...

# %%
nutrition.nlargest(10,'potassium')
# Out:
#                                                     serving_size  calories  \
# name
# Leavening agents, cream of tartar                          100.0     258.0
# Leavening agents, low-sodium, baking powder                100.0      97.0
# Parsley, freeze-dried                                      100.0     271.0
# Beverages, powder, unsweetened, instant, tea               100.0     315.0
# Beverages, unsweetened, decaffeinated, instant,...         100.0     315.0
# Spices, dried, chervil                                     100.0     237.0
# Spices, dried, coriander leaf                              100.0     279.0
# Celery flakes, dried                                       100.0     319.0
# Beverages, powder, regular, instant, coffee                100.0     353.0
# Beverages, half the caffeine, regular, instant,...         100.0     352.0
#
#                                                     total_fat  saturated_fat  \
# name
# ...

# %%
nutrition.nsmallest(10,['sodium','calories','folic_acid'])
# Out:
#                                                     serving_size  calories  \
# name
# Beverages, well, tap, water                                100.0       0.0
# Water, NAYA, non-carbonated, bottled                       100.0       0.0
# Beverages, decaffeinated, brewed, green, tea               100.0       0.0
# Beverages, EVIAN, non-carbonated, bottled, water           100.0       0.0
# Beverages, CALISTOGA, non-carbonated, bottled, ...         100.0       0.0
# Beverages, DANNON, non-carbonated, bottled, water          100.0       0.0
# Sweetener, herbal extract powder from Stevia leaf          100.0       0.0
# Beverages, CRYSTAL GEYSER, non-carbonated, bott...         100.0       0.0
# Babyfood, without added fluoride., GERBER, bott...         100.0       0.0
# Beverages, AQUAFINA, PEPSI, non-carbonated, bot...         100.0       0.0
#
#                                                     total_fat  saturated_fat  \
# name
# ...

# %%
nutrition.loc[:,'vitamin_b12'].nlargest(10)
# Out:
# name
# Mollusks, moist heat, cooked, mixed species, clam                                   98.89
# Beef, boiled, cooked, variety meats and by-products liver, imported, New Zealand    96.00
# Lamb, raw, liver, variety meats and by-products                                     90.05
# Lamb, pan-fried, cooked, liver, variety meats and by-products                       85.70
# Veal, braised, cooked, liver, variety meats and by-products                         84.60
# Beef, raw, liver, variety meats and by-products, imported, New Zealand              84.50
# Beef, pan-fried, cooked, liver, variety meats and by-products                       83.13
# Lamb, braised, cooked, kidneys, variety meats and by-products                       78.90
# Lamb, braised, cooked, liver, variety meats and by-products                         76.50
# Veal, pan-fried, cooked, liver, variety meats and by-products                       72.50
# Name: vitamin_b12, dtype: float64

# %%
nutrition.vitamin_b12.nlargest(10)
# Out:
# name
# Mollusks, moist heat, cooked, mixed species, clam                                   98.89
# Beef, boiled, cooked, variety meats and by-products liver, imported, New Zealand    96.00
# Lamb, raw, liver, variety meats and by-products                                     90.05
# Lamb, pan-fried, cooked, liver, variety meats and by-products                       85.70
# Veal, braised, cooked, liver, variety meats and by-products                         84.60
# Beef, raw, liver, variety meats and by-products, imported, New Zealand              84.50
# Beef, pan-fried, cooked, liver, variety meats and by-products                       83.13
# Lamb, braised, cooked, kidneys, variety meats and by-products                       78.90
# Lamb, braised, cooked, liver, variety meats and by-products                         76.50
# Veal, pan-fried, cooked, liver, variety meats and by-products                       72.50
# Name: vitamin_b12, dtype: float64

# %%
nutrition.filter(regex='[Ee]ggplant',axis=0).sodium.nlargest(1)
# Out:
# name
# Eggplant, pickled    1674.0
# Name: sodium, dtype: float64

# %%
nutrition.sample(4).sample(2,axis=1)
# Out:
#                                                     glutamic_acid  methionine
# name
# Beef, raw, choice, trimmed to 0" fat, separable...          3.685       0.600
# KEEBLER, Buttercrisps Crackers, TOASTEDS                    0.000       0.000
# Veal, braised, cooked, separable lean and fat, ...          4.420       0.652
# Lamb, raw, choice, trimmed to 1/4" fat, separab...          2.600       0.460

# %%
nutrition = nutrition.dropna(axis=0,how='any')

# %%
nutrition[nutrition.vitamin_c.between(20,40)].calories.nsmallest(1)
# Out:
# name
# Asparagus, with salt, drained, boiled, cooked, frozen    18.0
# Name: calories, dtype: float64

# %%
m = nutrition.vitamin_c.mean()

# %%
m2std = m + nutrition.vitamin_c.std()*2

# %%
m3std = m + nutrition.vitamin_c.std()*3

# %%
result = nutrition[nutrition.vitamin_c.between(m2std,m3std)]

# %%
result.vitamin_c.describe()
# Out:
# count     17.000000
# mean     119.617647
# std        9.190772
# min      101.800000
# 25%      118.000000
# 50%      120.000000
# 75%      120.000000
# max      138.000000
# Name: vitamin_c, dtype: float64
